# %% [markdown]
# # Project 1: Customer Database
# **This is the first of three mandatory projects to be handed in as part of the assessment for the course 02807 Computational Tools for Data Science at Technical University of Denmark, autumn 2019.**
#
# #### Practical info
# - **The project is to be done in groups of at most 3 students**
# - **Each group has to hand in _one_ Jupyter notebook (this notebook) with their solution**
# - **The hand-in of the notebook is due 2019-10-13, 23:59 on DTU Inside**
#
# #### Your solution
# - **Your solution should be in Python**
# - **For each question you may use as many cells for your solution as you like**
# - **You should document your solution and explain the choices you've made (for example by using multiple cells and use Markdown to assist the reader of the notebook)**
# - **You should not remove the problem statements, and you should not modify the structure of the notebook**
# - **Your notebook should be runnable, i.e., clicking [>>] in Jupyter should generate the result that you want to be assessed**
# - **You are not expected to use machine learning to solve any of the exercises**
# - **You will be assessed according to correctness and readability of your code, choice of solution, choice of tools and libraries, and documentation of your solution**

# %% [markdown]
# ## Introduction
# Your team has been hired by the company X as data scientists. X makes gadgets for a wide range of industrial and commercial clients.
#
# As in-house data scientists, your teams first task, as per request from your new boss, is to optimize business operations. You have decided that a good first step would be to analyze the companys historical sales data to gain a better understanding of where profit is coming from. It may also reveal some low hanging fruit in terms of business opportunities.
#
# To get started, you have called the IT department to get access to the customer and sales transactions database. To your horror you've been told that such a database doens't exist, and the only record of sales transactions is kept by John from finance in an Excel spreadsheet. So you've emailed John asking for a CSV dump of the spreadsheet...
#
# In this project you need to clean the data you got from John, enrich it with further data, prepare a database for the data, and do some data analysis. The project is comprised of five parts. They are intended to be solved in the order they appear, but it is highly recommended that you read through all of them and devise an overall strategy before you start implementing anything.

# %% [markdown]
# ## Part 1: Cleaning the data
# John has emailed you the following link to the CSV dump you requested.
#
# - [transactions.csv](https://raw.githubusercontent.com/patrickcording/02807-comp-tools/master/docker/work/data/transactions.csv)
#
# It seems as though he has been a bit sloppy when keeping the records.
#
# In this part you should:
# - Explain what the data is
# - Clean it to prepare it for inserting into a database and doing data analysis

# %% [markdown]
# ---
# ### Solution

# %%
import pandas as pd
import numpy as np
import random
import re
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import bottleneck as bn
import math

# %%
df=pd.read_csv("https://raw.githubusercontent.com/patrickcording/02807-comp-tools/master/docker/work/data/transactions.csv",encoding="utf-8")

# %%
df.head()
# Out:
#          part        company country          city     price  \
# 0  54868-5165  Chatterbridge   Spain     Barcelona   784.79€
# 1  60505-2867           Lajo  Greece  Thessaloniki   187.99€
# 2   24385-268      Flipstorm  Greece        Athens   221.73€
# 3   76117-001    Twitterbeat  France        Annecy  1075.82€
# 4  44946-1046  Chatterbridge   Spain     Barcelona   412.55€
#
#                   date
# 0  2016-01-02 00:01:05
# 1  2016-01-02 00:05:26
# 2  2016-01-02 00:18:30
# 3  2016-01-02 02:32:30
# 4  2016-01-02 04:51:55

# %%
df.describe()
# Out:
#              part     company   country       city  price        date
# count       20558       20568     18397      20535  20567       20568
# unique        100          35        13         30  19214       20552
# top     17156-617  Thoughtmix  Portugal  Amadora\t      -  10/04/2017
# freq          300        2795      7383       2787      5           7

# %%
df.dtypes
# Out:
# part       object
# company    object
# country    object
# city       object
# price      object
# date       object
# dtype: object

# %%
for column in df.columns:
    print("Data type in {} is {}.".format(column,type(df[column][0])))
# Out:
# Data type in part is <class 'str'>.
# Data type in company is <class 'str'>.
# Data type in country is <class 'str'>.
# Data type in city is <class 'str'>.
# Data type in price is <class 'str'>.
# Data type in date is <class 'str'>.

# %%
# check for empty string
for column in df.columns:
    print("" in df[column])
# Out:
# False
# False
# False
# False
# False
# False

# %%
# check for NaN
for column in df.columns:
    print("column {} has {} null value".format(column, df[column].isnull().sum().sum()))
# Out:
# column part has 10 null value
# column company has 0 null value
# column country has 2171 null value
# column city has 33 null value
# column price has 1 null value
# column date has 0 null value

# %% [markdown]
# ### part column

# %%
df.part.nunique()
# Out:
# 100

# %%
df.part.value_counts(dropna = False).head()
# Out:
# 17156-617     300
# 37205-992     295
# 52959-433     293
# 0268-6107     293
# 54868-0823    292
# Name: part, dtype: int64

# %% [markdown]
# #### handle missing values in `part`

# %%
df[df.part.isnull()]
# Out:
#       part      company        country          city     price  \
# 14916  NaN        Yozio         Greece        Patras   518.38€
# 14917  NaN  Brainsphere       Portugal         Braga   957.24€
# 14918  NaN         Lajo         Greece  Thessaloniki   966.06€
# 14919  NaN       Roodel       Portugal       Aranhas   873.65€
# 17524  NaN        Yozio         Greece        Patras   627.32€
# 17525  NaN   Thoughtmix       Portugal     Amadora\t    825.8€
# 17526  NaN      Gabcube       Portugal        Almada   188.31€
# 17527  NaN     Buzzbean        Germany    Düsseldorf   429.67€
# 17528  NaN      Zoonder  United States        Boston   $521.72
# 17529  NaN  Twitterbeat         France        Annecy  1031.46€
#
#                       date
# 14916  2018-02-17 21:43:43
# 14917  2018-02-17 22:12:24
# 14918  2018-02-17 22:54:49
# 14919  2018-02-17 23:36:52
# 17524  2018-07-12 03:28:46
# 17525  2018-07-12 05:34:07
# 17526  2018-07-12 06:49:44
# 17527  2018-07-12 07:03:50
# 17528  2018-07-12 08:38:56
# 17529  2018-07-12 09:48:17

# %%
prop_nan_part = len(df[df.part.isnull()])/len(df)
prop_nan_part
# Out:
# 0.0004861921431349669

# %% [markdown]
# Since the proportion of missing values in the part column is only 0.049% of the entire dataset, we can remove the rows with missing part entries.

# %%
df=df.dropna(subset=['part'])

# %%
df[df.part.isnull()]
# Out:
# Empty DataFrame
# Columns: [part, company, country, city, price, date]
# Index: []

# %% [markdown]
# ### company column

# %% [markdown]
# #### clean strings in `company`

# %%
df.company.unique()
# Out:
# array(['Chatterbridge', 'Lajo', 'Flipstorm', 'Twitterbeat', 'Voomm',
#        'Buzzbean', 'Zooxo', 'Brainsphere', 'Thoughtmix', 'Wordify',
#        'Teklist', 'Avaveo', 'Ntags', 'Innojam', 'Shufflebeat', 'Zoonder',
#        'Kanoodle', 'Gabcube', 'Roodel', 'Riffpath', 'Eimbee', 'Yozio',
#        'Rhycero', 'Realpoint', 'Gabtune', 'Bubblemix', 'Gevee', 'Tagtune',
#        'Zooxo.', 'Laj0', 'Ntagz', ' -', ' a', 'aa', 'Thoughtmixz'],
#       dtype=object)

# %%
df.company.value_counts(dropna=False)
# Out:
# Thoughtmix       2794
# Twitterbeat      2267
# Zooxo            1670
# Chatterbridge    1589
# Shufflebeat      1553
# Ntags            1514
# Buzzbean         1253
# Brainsphere      1241
# Flipstorm        1193
# Wordify           968
# Yozio             653
# Roodel            626
# Eimbee            498
# Zoonder           453
# Teklist           428
# Gabcube           356
# Voomm             250
# Lajo              219
# Avaveo            212
# Rhycero           204
# Realpoint         158
# Riffpath          151
# Kanoodle          127
# Bubblemix          54
# Innojam            44
# Gevee              36
# Gabtune            27
# Tagtune            12
# Zooxo.              2
# aa                  1
# Laj0                1
#  -                  1
# Thoughtmixz         1
# Ntagz               1
#  a                  1
# Name: company, dtype: int64

# %% [markdown]
# From the above result, it can be seen that some erroneous company names/poorly formatted company names. These include:
# * ` a`,`aa`,` -` each has occurred once in the dataset. They are likely to be the erroneous entries. Simply remove them.
# * `Laj0` should be standardized to `Lajo`. Likewise, `Zooxo.` should be standardized to `Zooxo`; `Thoughtmixz` should be standardized to `Thoughtmix`; `Ntagz` should be standardized to `Ntags`

# %%
df.company = df.company.replace([' a','aa',' -'], '')
df=df[df.company != '']

# %%
df.company = df.company.replace('Zooxo.','Zooxo')
df.company = df.company.replace('Laj0','Lajo')
df.company = df.company.replace('Thoughtmixz','Thoughtmix')
df.company = df.company.replace('Ntagz','Ntags')

# %%
df.company.value_counts(dropna=False)
# Out:
# Thoughtmix       2795
# Twitterbeat      2267
# Zooxo            1672
# Chatterbridge    1589
# Shufflebeat      1553
# Ntags            1515
# Buzzbean         1253
# Brainsphere      1241
# Flipstorm        1193
# Wordify           968
# Yozio             653
# Roodel            626
# Eimbee            498
# Zoonder           453
# Teklist           428
# Gabcube           356
# Voomm             250
# Lajo              220
# Avaveo            212
# Rhycero           204
# Realpoint         158
# Riffpath          151
# Kanoodle          127
# Bubblemix          54
# Innojam            44
# Gevee              36
# Gabtune            27
# Tagtune            12
# Name: company, dtype: int64

# %%
df[df['company'].isnull()]
# Out:
# Empty DataFrame
# Columns: [part, company, country, city, price, date]
# Index: []

# %% [markdown]
# ### country column

# %% [markdown]
# #### clean strings in `country`

# %%
df.country.unique()
# Out:
# array(['Spain', 'Greece', 'France', 'Germany', 'United Kingdom',
#        'Portugal', 'United States', 'Netherlands', 'Japan', 'Switzerland',
#        nan, 'US', 'Tyskland', 'Portuga'], dtype=object)

# %% [markdown]
# From the `unique()` result, we can see that `United States` and `US` are the same and thus should be standardized.
# <br>
# Similarly, `Portugal` and `Portuga` should be standardized.
# <br>
# Additionally, `Tyskland` means `Germany` in Swedish. Thus they need to be standardized too.

# %%
df.country = df.country.replace('US', 'United States')
df.country = df.country.replace('Portuga', 'Portugal')
df.country = df.country.replace('Tyskland', 'Germany')

# %%
df.country.unique()
# Out:
# array(['Spain', 'Greece', 'France', 'Germany', 'United Kingdom',
#        'Portugal', 'United States', 'Netherlands', 'Japan', 'Switzerland',
#        nan], dtype=object)

# %% [markdown]
# #### handle missing values in  `country`

# %%
df[df.country.isnull()].head()
# Out:
#             part      company country        city    price  \
# 2528  52380-1102      Teklist     NaN      Arnhem   357.78
# 2947   52125-136  Brainsphere     NaN       Braga  493.94€
# 2956   16714-295      Teklist     NaN      Arnhem   624.4€
# 2994   76335-006     Buzzbean     NaN  Düsseldorf  355.24€
# 3948   54473-578  Brainsphere     NaN       Braga  123.32€
#
#                      date
# 2528  2016-04-21 04:07:31
# 2947  2016-05-10 11:13:43
# 2956  2016-05-10 21:57:15
# 2994  2016-05-12 15:17:37
# 3948  2016-07-01 01:09:40

# %%
len(df[df.country.isnull()])
# Out:
# 2171

# %%
prop_nan_country = len(df[df.country.isnull()])/len(df)
prop_nan_country
# Out:
# 0.1056190707856969

# %% [markdown]
# Since the fraction of missing values in the country column is 10.43% of the entire dataset which is considerably large, we cannot simply remove the rows with missing countries entries as doing so will result in much information being lost.
# <br>
# <br>
# Instead, we can deduce some of the country names from their corresponding cities.

# %%
df.groupby(['city'])['country'].value_counts(dropna = False).head()
# Out:
# city       country
# Almada     Portugal     323
#            NaN           33
# Amadora\t  Portugal    2511
#            NaN          275
# Amiens     France       452
# Name: country, dtype: int64

# %%
city_country_mapping = df.groupby(['city'])['country'].apply(lambda grp: list(grp.value_counts().index)[0]).to_dict()
city_country_mapping
# Out:
# {'Almada': 'Portugal',
#  'Amadora\t': 'Portugal',
#  'Amiens': 'France',
#  'Amsterdam': 'Netherlands',
#  'Annecy': 'France',
#  'Aranhas': 'Portugal',
#  'Arcueil': 'France',
#  'Arnhem': 'Netherlands',
#  'Asaka': 'Japan',
#  'Athens': 'Greece',
#  'Barcelona': 'Spain',
#  'Boston': 'United States',
#  'Braga': 'Portugal',
#  'Champagnole': 'France',
#  'Düsseldorf': 'Germany',
#  'Heraklion': 'Greece',
#  'Lisbon': 'Portugal',
#  'London': 'United Kingdom',
#  'Lyon': 'France',
#  'Monção': 'Portugal',
#  'Nanterre': 'France',
#  'New York': 'United States',
#  'Nice': 'France',
#  'Niihama': 'Japan',
#  'Paris': 'France',
#  'Patras': 'Greece',
#  'Porto': 'Portugal',
#  'Thessaloniki': 'Greece',
#  'Vila Fria': 'Portugal',
#  'Zürich': 'Switzerland'}

# %%
df[df.country.isnull()].index
# Out:
# Int64Index([ 2528,  2947,  2956,  2994,  3948,  3949,  3950,  3951,  3952,
#              3953,
#             ...
#             12843, 12978, 13721, 14438, 16146, 16147, 16148, 16149, 16150,
#             16151],
#            dtype='int64', length=2171)

# %%
def impute_countries(row):
    try:
        res=city_country_mapping[row.city]
    except KeyError:
        res=float('NaN')
    return res

# %%
df.country = df.apply(impute_countries, axis = 1)

# %%
len(df[df.country.isna()])
# Out:
# 33

# %%
df[df.country.isna()]
# Out:
#              part      company country city      price                 date
# 3136    68462-565  Brainsphere     NaN  NaN   1057.85€  2016-05-20 08:59:53
# 3137    54092-515  Shufflebeat     NaN  NaN    772.92€  2016-05-20 09:55:24
# 3138    0185-0373  Brainsphere     NaN  NaN    1012.8€  2016-05-20 10:42:10
# 12820   50563-113        Ntags     NaN  NaN    507.49€  2017-10-20 04:03:11
# 12821  55154-5057  Brainsphere     NaN  NaN    421.64€  2017-10-20 13:23:34
# 12822  36987-1697        Ntags     NaN  NaN    937.08€  2017-10-20 18:25:00
# 12823   68462-565   Thoughtmix     NaN  NaN    777.58€  2017-10-20 21:21:18
# 12824   0603-6134        Yozio     NaN  NaN    775.05€  2017-10-20 23:17:59
# 12825  58118-5060        Yozio     NaN  NaN    157.53€  2017-10-20 23:49:53
# 12826   51060-032   Thoughtmix     NaN  NaN    176.36€  2017-10-21 00:11:55
# 12827   16714-295  Twitterbeat     NaN  NaN    348.26€  2017-10-21 01:24:52
# 12828   0603-6134        Ntags     NaN  NaN    714.66€  2017-10-21 01:53:26
# 12829   52125-136        Zooxo     NaN  NaN    £616.08  2017-10-21 04:26:42
# 12830   70253-307   Thoughtmix     NaN  NaN    880.07€  2017-10-21 06:19:34
# 12831   49967-724        Ntags     NaN  NaN     593.0€  2017-10-21 08:04:12
# 12832  54868-5165      Zoonder     NaN  NaN    $879.56  2017-10-21 09:35:27
# 12833  65044-3014        Zooxo     NaN  NaN    £738.09  2017-10-21 10:17:08
# 12834   51346-145  Brainsphere     NaN  NaN    939.35€  2017-10-21 15:06:59
# 12835  36987-1697      Wordify     NaN  NaN     $371.3  2017-10-21 15:59:29
# 12836  63629-2733      Teklist     NaN  NaN    236.48€  2017-10-21 17:14:47
# 12837   49035-530      Teklist     NaN  NaN   1160.47€  2017-10-21 22:49:57
# 12838  62670-4404  Shufflebeat     NaN  NaN    517.91€  2017-10-22 02:54:15
# 12839   0185-0373   Thoughtmix     NaN  NaN   1007.71€  2017-10-22 04:16:08
# 12840   49967-724   Thoughtmix     NaN  NaN    586.71€  2017-10-22 04:34:36
# 12841   59779-601        Ntags     NaN  NaN     171.8€  2017-10-22 05:00:42
# 12842   35356-325  Shufflebeat     NaN  NaN    436.67€  2017-10-22 05:10:16
# 12843   49349-471        Ntags     NaN  NaN   1030.42€  2017-10-22 07:11:01
# 16146   58596-001      Wordify     NaN  NaN    $492.17  2018-04-26 08:00:25
# 16147   36800-952   Thoughtmix     NaN  NaN    358.03€  2018-04-26 08:16:56
# 16148   51346-126     Kanoodle     NaN  NaN  ¥15949.24  2018-04-26 16:21:00
# 16149   49348-574   Thoughtmix     NaN  NaN    295.01€  2018-04-26 19:16:45
# 16150   0228-2167        Zooxo     NaN  NaN    £682.83  2018-04-26 22:20:00
# 16151   13537-259   Thoughtmix     NaN  NaN    865.37€  2018-04-26 22:34:15

# %% [markdown]
# ### city column

# %% [markdown]
# #### clean strings in `city`

# %%
df.city.unique()
# Out:
# array(['Barcelona', 'Thessaloniki', 'Athens', 'Annecy', 'Paris',
#        'Düsseldorf', 'London', 'Braga', 'Nanterre', 'Amadora\t',
#        'New York', 'Arnhem', 'Nice', 'Lisbon', 'Amsterdam', 'Porto',
#        'Boston', 'Niihama', 'Almada', 'Aranhas', 'Heraklion', 'Amiens',
#        'Patras', 'Arcueil', 'Lyon', 'Asaka', 'Champagnole', 'Zürich', nan,
#        'Monção', 'Vila Fria'], dtype=object)

# %% [markdown]
# Result from `unique()` shows that there is an additional `\t` in the city `Amadora`. Remove the`\t`s:

# %%
df.city = df.city.str.replace("\t","")

# %%
df.city.unique()
# Out:
# array(['Barcelona', 'Thessaloniki', 'Athens', 'Annecy', 'Paris',
#        'Düsseldorf', 'London', 'Braga', 'Nanterre', 'Amadora', 'New York',
#        'Arnhem', 'Nice', 'Lisbon', 'Amsterdam', 'Porto', 'Boston',
#        'Niihama', 'Almada', 'Aranhas', 'Heraklion', 'Amiens', 'Patras',
#        'Arcueil', 'Lyon', 'Asaka', 'Champagnole', 'Zürich', nan, 'Monção',
#        'Vila Fria'], dtype=object)

# %% [markdown]
# #### handle missing values in `city`

# %%
df[df.city.isnull()]
# Out:
#              part      company country city      price                 date
# 3136    68462-565  Brainsphere     NaN  NaN   1057.85€  2016-05-20 08:59:53
# 3137    54092-515  Shufflebeat     NaN  NaN    772.92€  2016-05-20 09:55:24
# 3138    0185-0373  Brainsphere     NaN  NaN    1012.8€  2016-05-20 10:42:10
# 12820   50563-113        Ntags     NaN  NaN    507.49€  2017-10-20 04:03:11
# 12821  55154-5057  Brainsphere     NaN  NaN    421.64€  2017-10-20 13:23:34
# 12822  36987-1697        Ntags     NaN  NaN    937.08€  2017-10-20 18:25:00
# 12823   68462-565   Thoughtmix     NaN  NaN    777.58€  2017-10-20 21:21:18
# 12824   0603-6134        Yozio     NaN  NaN    775.05€  2017-10-20 23:17:59
# 12825  58118-5060        Yozio     NaN  NaN    157.53€  2017-10-20 23:49:53
# 12826   51060-032   Thoughtmix     NaN  NaN    176.36€  2017-10-21 00:11:55
# 12827   16714-295  Twitterbeat     NaN  NaN    348.26€  2017-10-21 01:24:52
# 12828   0603-6134        Ntags     NaN  NaN    714.66€  2017-10-21 01:53:26
# 12829   52125-136        Zooxo     NaN  NaN    £616.08  2017-10-21 04:26:42
# 12830   70253-307   Thoughtmix     NaN  NaN    880.07€  2017-10-21 06:19:34
# 12831   49967-724        Ntags     NaN  NaN     593.0€  2017-10-21 08:04:12
# 12832  54868-5165      Zoonder     NaN  NaN    $879.56  2017-10-21 09:35:27
# 12833  65044-3014        Zooxo     NaN  NaN    £738.09  2017-10-21 10:17:08
# 12834   51346-145  Brainsphere     NaN  NaN    939.35€  2017-10-21 15:06:59
# 12835  36987-1697      Wordify     NaN  NaN     $371.3  2017-10-21 15:59:29
# 12836  63629-2733      Teklist     NaN  NaN    236.48€  2017-10-21 17:14:47
# 12837   49035-530      Teklist     NaN  NaN   1160.47€  2017-10-21 22:49:57
# 12838  62670-4404  Shufflebeat     NaN  NaN    517.91€  2017-10-22 02:54:15
# 12839   0185-0373   Thoughtmix     NaN  NaN   1007.71€  2017-10-22 04:16:08
# 12840   49967-724   Thoughtmix     NaN  NaN    586.71€  2017-10-22 04:34:36
# 12841   59779-601        Ntags     NaN  NaN     171.8€  2017-10-22 05:00:42
# 12842   35356-325  Shufflebeat     NaN  NaN    436.67€  2017-10-22 05:10:16
# 12843   49349-471        Ntags     NaN  NaN   1030.42€  2017-10-22 07:11:01
# 16146   58596-001      Wordify     NaN  NaN    $492.17  2018-04-26 08:00:25
# 16147   36800-952   Thoughtmix     NaN  NaN    358.03€  2018-04-26 08:16:56
# 16148   51346-126     Kanoodle     NaN  NaN  ¥15949.24  2018-04-26 16:21:00
# 16149   49348-574   Thoughtmix     NaN  NaN    295.01€  2018-04-26 19:16:45
# 16150   0228-2167        Zooxo     NaN  NaN    £682.83  2018-04-26 22:20:00
# 16151   13537-259   Thoughtmix     NaN  NaN    865.37€  2018-04-26 22:34:15

# %%
len(df[df.city.isnull()])
# Out:
# 33

# %%
df.groupby(["company","country",'city']).count()
# Out:
#                                            part  price  date
# company       country        city
# Avaveo        France         Nice           212    212   212
# Brainsphere   Portugal       Braga         1236   1236  1236
#                              Monção           1      1     1
# Bubblemix     Japan          Asaka           54     54    54
# Buzzbean      Germany        Düsseldorf    1253   1253  1253
# Chatterbridge Spain          Barcelona     1589   1589  1589
# Eimbee        France         Amiens         498    498   498
# Flipstorm     France         Nanterre       381    381   381
#               Greece         Athens         812    812   812
# Gabcube       Portugal       Almada         356    356   356
# Gabtune       France         Lyon            27     27    27
# Gevee         France         Champagnole     36     36    36
# Innojam       Netherlands    Amsterdam       44     44    44
# Kanoodle      Japan          Niihama        126    126   126
# Lajo          Greece         Thessaloniki   220    220   220
# Ntags         Portugal       Lisbon        1509   1509  1509
# Realpoint     Portugal       Lisbon         158    158   158
# Rhycero       France         Arcueil        204    204   204
# Riffpath      Greece         Heraklion      151    151   151
# Roodel        Portugal       Aranhas        626    625   626
# Shufflebeat   Portugal       Porto         1550   1550  1550
# Tagtune       Switzerland    Zürich          12     12    12
# Teklist       Netherlands    Arnhem         426    426   426
# Thoughtmix    Portugal       Amadora       2786   2786  2786
#                              Vila Fria        1      1     1
# Twitterbeat   France         Annecy        2266   2266  2266
# Voomm         France         Paris          250    250   250
# Wordify       United States  New York       966    966   966
# Yozio         Greece         Patras         651    651   651
# Zoonder       United States  Boston         452    452   452
# Zooxo         United Kingdom London        1669   1669  1669

# %%
prop_nan_city = len(df[df.city.isnull()])/len(df)
prop_nan_city
# Out:
# 0.001605448795913403

# %% [markdown]
# Since the proportion of missing values in the city column is only 0.16% of the entire dataset, we can remove the rows with missing city entries.
# <br>
# <br>
# Moreover, the table above shows that all but three records have missing values in both country and city. This implies that dropping records that have missing values in the city column does not cause a big loss in information in the country column, since only three such country records are not null.

# %%
df=df.dropna(subset=['city'])

# %%
df[df.city.isnull()]
# Out:
# Empty DataFrame
# Columns: [part, company, country, city, price, date]
# Index: []

# %% [markdown]
# ### date column

# %%
# string to datetime object
df['parsed_date'] = pd.to_datetime(df['date'],errors='coerce', infer_datetime_format=True)

# %%
# checking
df[df.parsed_date.isnull()]
# Out:
#             part      company   country     city    price  \
# 3539   17156-617   Thoughtmix  Portugal  Amadora  791.86€
# 3540  54868-5165  Shufflebeat  Portugal    Porto  525.24€
#
#                      date parsed_date
# 3539  2016-06-32 07:22:28         NaT
# 3540  2016-06-32 08:08:48         NaT

# %%
df = df.dropna()

# %% [markdown]
# ### price column

# %%
# original intention was to find all currency signs present
# but it turned out that there are other poorly formatted cells other than currency signs
res=[]
for p in df.price:
    for c in p:
        if c.isdigit() == False:
            res.append(c)
x=np.array(res)
np.unique(x)
# Out:
# array(['$', '-', '.', 'a', 'd', 'i', 'n', 'o', 'v', '£', '¥', '€'],
#       dtype='<U1')

# %%
# find what are those cells
res=[]
for p in df.price:
    for c in p:
        if c in ['a', 'd', 'i', 'n', 'o', 'v']:
            print(p)
            break
# Out:
# void
# void
# na
# na
# na

# %%
print(len(df))
df=df[df.price != 'void']
df=df[df.price != 'na']
print(len(df))
# Out:
# 20519
# 20514

# %%
def parse_price(string):
    amount=re.match(r'([^-\d\.]?)(-?\d*\.?\d*)([\D]?)', str(string))
    lst=[i for i in amount.groups() if i != '']
#     if len(lst) != 2:
#         return float('NaN')
    try:
        res=float(lst[0])
    except ValueError:
        res=float(lst[1])
    return res

# %%
def parse_symbol(string):
    amount=re.match(r'([^-\d\.]?)(-?\d*\.?\d*)([\D]?)', str(string))
    lst=[i for i in amount.groups() if i != '']
#     if len(lst) != 2:
#         return float('NaN')
    try:
        number=float(lst[0])
        sign=lst[1]
    except ValueError:
        sign=lst[0]
    return sign

# %%
def find_currency(string):
    currency=re.findall("[€$¥£]",string)
    if currency:
        symbol=currency[0]
        if symbol == "€":
            return "EUR"
        elif symbol == "$":
            return "USD"
        elif symbol == "¥":
            return "CNY"
        elif symbol == "£":
            return "GBP"
    else:
        print("error: can't find currenct symbol in {}".format(string))

# %%
df["currency"]=df.price.apply(find_currency)
# Out:
# error: can't find currenct symbol in 465.6
# error: can't find currenct symbol in 1266.68
# error: can't find currenct symbol in 829.3
# error: can't find currenct symbol in 357.78
# error: can't find currenct symbol in -
# error: can't find currenct symbol in -
# error: can't find currenct symbol in -
# error: can't find currenct symbol in -
# error: can't find currenct symbol in -

# %%
df=df[df['price'] != "465.6"]
df=df[df['price'] != "1266.68"]
df=df[df['price'] != "829.3"]
df=df[df['price'] != "357.78"]
df=df[df['price'] != "-"]

# %%
df['price_amount']=df.price.apply(parse_price)

# %%
df['price_symbol']=df.price.apply(parse_symbol)

# %%
df.tail()
# Out:
#              part      company   country     city     price  \
# 20563   21695-267       Roodel  Portugal  Aranhas   606.37€
# 20564   49999-737   Thoughtmix  Portugal  Amadora   828.37€
# 20565   52343-025  Brainsphere  Portugal    Braga    686.1€
# 20566  49288-0285    Flipstorm    Greece   Athens  1051.08€
# 20567   43419-018    Flipstorm    Greece   Athens   139.56€
#
#                       date         parsed_date currency  price_amount  \
# 20563  2018-12-31 20:48:14 2018-12-31 20:48:14      EUR        606.37
# 20564  2018-12-31 21:24:17 2018-12-31 21:24:17      EUR        828.37
# 20565  2018-12-31 21:38:02 2018-12-31 21:38:02      EUR        686.10
# 20566  2019-02-21 20:05:00 2019-02-21 20:05:00      EUR       1051.08
# 20567  2019-05-14 22:48:39 2019-05-14 22:48:39      EUR        139.56
#
#       price_symbol
# 20563            €
# 20564            €
# 20565            €
# 20566            €
# 20567            €

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df=df.drop(columns='date')
df.rename(columns={"parsed_date" : "date", 
                   "currency": "currency_name",
                   "price_symbol":"currency_symbol"}, inplace=True)

# %%
df.head()
# Out:
#          part        company country          city     price  \
# 0  54868-5165  Chatterbridge   Spain     Barcelona   784.79€
# 1  60505-2867           Lajo  Greece  Thessaloniki   187.99€
# 2   24385-268      Flipstorm  Greece        Athens   221.73€
# 3   76117-001    Twitterbeat  France        Annecy  1075.82€
# 4  44946-1046  Chatterbridge   Spain     Barcelona   412.55€
#
#                  date currency_name  price_amount currency_symbol
# 0 2016-01-02 00:01:05           EUR        784.79               €
# 1 2016-01-02 00:05:26           EUR        187.99               €
# 2 2016-01-02 00:18:30           EUR        221.73               €
# 3 2016-01-02 02:32:30           EUR       1075.82               €
# 4 2016-01-02 04:51:55           EUR        412.55               €

# %% [markdown]
# ---
# ## Part 2: Enriching the data

# %% [markdown]
# A common task for a data scientists is to combine or enrich data from internal sources with data available from external sources. The purpose of this can be either to fix issues with the data or to make it easier to derive insights from the data.
#
# In this part you should enrich your data with data from at least one external source. You may look to part 4 for some  inspiration as to what is required. Your solution should be automated, i.e., you can not ask the reader of your notebook to download any data manually. You should argue why and what you expect to achieve by the enrichments you are doing.

# %% [markdown]
# ---
# ### Solution

# %%
import datetime
from forex_python.converter import CurrencyRates

# %% [markdown]
# #### External Data 1 --> Exchange Rate
# <describe why use this particular external data, how it can enhance the existing dataset, etc.>

# %%
c = CurrencyRates()

# %%
def ToUSD(currency,date):
    return c.convert(currency, 'USD', 1 , date)

# %%
# USD=[]
# dic={}
# for i in range(len(df)):
#     if i == 2000:
#         print("I'm 10% done!")
#     if i == 5000:
#         print("Hang on, Ms.Pretty/Mr.Handsome. I'm doing my best!")
#     if i == 10000:
#         print("Yeah, I'm 50% done!")
#     if i == 15000:
#         print("Waiting is boring, why not sing a song? La la la ~")
#     if i == 20000:
#         print("Almost there, give me 10s!")
#     date=df.iloc[i,5].date()
#     currency=df.iloc[i,6]
#     key=(currency,date)
#     if key in dic:
#         USD.append(dic[key])
#     else:
#         dic[key] = ToUSD(currency,date)
#         USD.append(dic[key])
# print("YAS! I'm done!")

# %%
df['exchange_rate_to_USD'] = USD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-77212d56d1d1> in <module>
# ----> 1 df['exchange_rate_to_USD'] = USD
#
# NameError: name 'USD' is not defined

# %%
df['standardized_USD'] = df.price_amount * df.exchange_rate_to_USD

# %%
df.tail()

# %% [markdown]
# save the above dataframe as a pickle object for easy access:

# %%
with open(r"df.pickle", "wb") as output_file:
    pickle.dump(df, output_file)

# %% [markdown]
# #### External Data 2 --> GDP
# <describe why use this particular external data, how it can enhance the existing dataset, etc.>

# %%
GDP=pd.read_csv("https://raw.githubusercontent.com/YangYuesong0323/Computational_Tools/master/GDP.csv")

# %%
GDP=GDP.drop(columns=['Country Code','Indicator Name','Indicator Code'])

GDP=GDP.rename(columns={'Country Name':'country'})

GDP_long=pd.melt(GDP,id_vars=['country'], var_name='year', value_name='value')

# %%
GDP_long.head()
# Out:
#        country  year        value
# 0        Aruba  1960          NaN
# 1  Afghanistan  1960  537777811.1
# 2       Angola  1960          NaN
# 3      Albania  1960          NaN
# 4      Andorra  1960          NaN

# %% [markdown]
# #### External Data 3 --> Population
# <describe why use this particular external data, how it can enhance the existing dataset, etc.>

# %%
Population=pd.read_csv("https://raw.githubusercontent.com/YangYuesong0323/Computational_Tools/master/population.csv")

# %%
Population=Population.drop(columns=['Country Code','Indicator Name','Indicator Code'])

Population=Population.rename(columns={'Country Name':'country'})

Population_long=pd.melt(Population,id_vars=['country'], var_name='year', value_name='value')

# %%
Population_long.head()
# Out:
#        country  year      value
# 0        Aruba  1960    54211.0
# 1  Afghanistan  1960  8996973.0
# 2       Angola  1960  5454933.0
# 3      Albania  1960  1608800.0
# 4      Andorra  1960    13411.0

# %% [markdown]
# ---
# ## Part 3: Creating a database
# Storing data in a relational database has the advantages that it is persistent, fast to query, and it will be easier access for other employees at Weyland-Yutani.
#
# In this part you should:
# - Create a database and table(s) for the data
# - Insert data into the tables
#
# You may use SQLite locally to do this. You should argue why you choose to store your data the way you do.

# %% [markdown]
# ---
# ### Solution

# %% [markdown]
# #### create a database named `project1`

# %%
import sqlite3

# %%
conn = sqlite3.connect('project1.sqlite')
c = conn.cursor()

# %% [markdown]
# #### create a table named `customer` from the pandas dataframe `df`

# %% [markdown]
# Since the current dataframe `df` does not have a primary key, we create another column called `key` and fill this column with the index of each row, i.e. use the row index as the primary key

# %%
with open(r"df.pickle", "rb") as output_file:
    df = pickle.load(output_file)

# %%
df.insert(0, 'key', range(len(df)))

# %%
df.head()
# Out:
#    key        part        company country          city     price  \
# 0    0  54868-5165  Chatterbridge   Spain     Barcelona   784.79€
# 1    1  60505-2867           Lajo  Greece  Thessaloniki   187.99€
# 2    2   24385-268      Flipstorm  Greece        Athens   221.73€
# 3    3   76117-001    Twitterbeat  France        Annecy  1075.82€
# 4    4  44946-1046  Chatterbridge   Spain     Barcelona   412.55€
#
#                  date currency_name  price_amount currency_symbol  \
# 0 2016-01-02 00:01:05           EUR        784.79               €
# 1 2016-01-02 00:05:26           EUR        187.99               €
# 2 2016-01-02 00:18:30           EUR        221.73               €
# 3 2016-01-02 02:32:30           EUR       1075.82               €
# 4 2016-01-02 04:51:55           EUR        412.55               €
#
#    exchange_rate_to_USD  standardized_USD
# 0                1.0887        854.400873
# 1                1.0887        204.664713
# 2                1.0887        241.397451
# 3                1.0887       1171.245234
# 4                1.0887        449.143185

# %% [markdown]
# add two additional columns, year and months, to the dataframe `df`

# %%
df['year'] = df.date.apply(lambda x : x.year)
df['month'] = df.date.apply(lambda x : x.month)

# %%
df.head()
# Out:
#    key        part        company country          city     price  \
# 0    0  54868-5165  Chatterbridge   Spain     Barcelona   784.79€
# 1    1  60505-2867           Lajo  Greece  Thessaloniki   187.99€
# 2    2   24385-268      Flipstorm  Greece        Athens   221.73€
# 3    3   76117-001    Twitterbeat  France        Annecy  1075.82€
# 4    4  44946-1046  Chatterbridge   Spain     Barcelona   412.55€
#
#                  date currency_name  price_amount currency_symbol  \
# 0 2016-01-02 00:01:05           EUR        784.79               €
# 1 2016-01-02 00:05:26           EUR        187.99               €
# 2 2016-01-02 00:18:30           EUR        221.73               €
# 3 2016-01-02 02:32:30           EUR       1075.82               €
# 4 2016-01-02 04:51:55           EUR        412.55               €
#
#    exchange_rate_to_USD  standardized_USD  year  month
# 0                1.0887        854.400873  2016      1
# 1                1.0887        204.664713  2016      1
# 2                1.0887        241.397451  2016      1
# 3                1.0887       1171.245234  2016      1
# 4                1.0887        449.143185  2016      1

# %%
df.columns
# Out:
# Index(['key', 'part', 'company', 'country', 'city', 'price', 'date',
#        'currency_name', 'price_amount', 'currency_symbol',
#        'exchange_rate_to_USD', 'standardized_USD', 'year', 'month'],
#       dtype='object')

# %% [markdown]
# create the `customer` table with sqlite3

# %%
c.execute('''DROP TABLE IF EXISTS customer;''')
conn.commit()

# %%
c.execute('''CREATE TABLE IF NOT EXISTS customer(
key INTEGER PRIMARY KEY, 
part varchar(20), 
company varchar(20), 
country varchar(30), 
city varchar(20), 
price varchar(10), 
date DATETIME, 
currency_name varchar(3), 
price_amount float(10), 
currency_symbol varchar(1), 
exchange_rate_to_USD float(10), 
standardized_USD float(10),
year DATETIME,
month DATETIME,
FOREIGN KEY (company, year) REFERENCES gdp(company, year))''')
conn.commit()

# %%
df.to_sql('customer', conn, if_exists='replace', index=False)
conn.commit()

# %%
# code to test whether the sqlite table created is the same as the original pandas dataframe

c.execute('SELECT Count(*) FROM customer')
print('number of rows in the sqlite customer table is {}'.format(c.fetchone()[0]))
print('number of rows in the pandas df dataframe is {}'.format(len(df)))
conn.commit()
# Out:
# number of rows in the sqlite customer table is 20505
# number of rows in the pandas df dataframe is 20505

# %%
# code to test whether the sqlite table created is the same as the original pandas dataframe

c.execute('SELECT * FROM customer')
print('first row in the sqlite customer table is {}'.format(c.fetchone()))
print()
print('first row in the pandas df dataframe is {}'.format(tuple(df.iloc[0])))
conn.commit()
# Out:
# first row in the sqlite customer table is (0, '54868-5165', 'Chatterbridge', 'Spain', 'Barcelona', '784.79€', '2016-01-02 00:01:05', 'EUR', 784.79, '€', 1.0887, 854.4008729999999, 2016, 1)
#
# first row in the pandas df dataframe is (0, '54868-5165', 'Chatterbridge', 'Spain', 'Barcelona', '784.79€', Timestamp('2016-01-02 00:01:05'), 'EUR', 784.79, '€', 1.0887, 854.4008729999999, 2016, 1)

# %% [markdown]
# #### create a table named `gdp` from the pandas dataframe `GDP_long`

# %%
GDP_long.columns
# Out:
# Index(['country', 'year', 'value'], dtype='object')

# %%
c.execute('''DROP TABLE IF EXISTS gdp;''')
conn.commit()

# %% [markdown]
# None of the attributes can uniquely identify the row entries. However, we can uniquely identify a row by using `country` and `year` combined. Therefore, we set `country` and `year` as the composite key to the table.

# %%
c.execute('''CREATE TABLE IF NOT EXISTS gdp( 
country varchar(64), 
year varchar(10), 
value float(10),
PRIMARY KEY (country, year))''')
conn.commit()

# %%
GDP_long.to_sql('gdp', conn, if_exists='replace', index=False)
conn.commit()

# %%
# code to test whether the sqlite table created is the same as the original pandas dataframe

c.execute('SELECT Count(*) FROM gdp')
print('number of rows in the sqlite gdp table is {}'.format(c.fetchone()[0]))
print('number of rows in the pandas GDP_long dataframe is {}'.format(len(GDP_long)))
conn.commit()
# Out:
# number of rows in the sqlite gdp table is 15576
# number of rows in the pandas GDP_long dataframe is 15576

# %%
# code to test whether the sqlite table created is the same as the original pandas dataframe

c.execute('SELECT * FROM gdp')
print('first row in the sqlite gdp table is {}'.format(c.fetchone()))
print()
print('first row in the pandas GDP_long dataframe is {}'.format(tuple(GDP_long.iloc[0])))
conn.commit()
# Out:
# first row in the sqlite gdp table is ('Aruba', '1960', None)
#
# first row in the pandas GDP_long dataframe is ('Aruba', '1960', nan)

# %% [markdown]
# #### create a table named `population` from the pandas dataframe `Population_long`

# %%
Population_long.columns
# Out:
# Index(['country', 'year', 'value'], dtype='object')

# %%
c.execute('''DROP TABLE IF EXISTS population;''')
conn.commit()

# %% [markdown]
# None of the attributes can uniquely identify the row entries. However, we can uniquely identify a row by using `country` and `year` combined. Therefore, we set `country` and `year` as the composite key to the table.

# %%
c.execute('''CREATE TABLE IF NOT EXISTS population(
country varchar(64), 
year varchar(10), 
value float(10),
PRIMARY KEY (country, year))''')
conn.commit()

# %%
Population_long.to_sql('population', conn, if_exists='replace', index=False)
conn.commit()

# %%
# code to test whether the sqlite table created is the same as the original pandas dataframe

c.execute('SELECT Count(*) FROM population')
print('number of rows in the sqlite population table is {}'.format(c.fetchone()[0]))
print('number of rows in the pandas Population_long dataframe is {}'.format(len(Population_long)))
conn.commit()
# Out:
# number of rows in the sqlite population table is 15576
# number of rows in the pandas Population_long dataframe is 15576

# %%
# code to test whether the sqlite table created is the same as the original pandas dataframe

c.execute('SELECT * FROM population')
print('first row in the sqlite population table is {}'.format(c.fetchone()))
print()
print('first row in the pandas Population_long dataframe is {}'.format(tuple(Population_long.iloc[0])))
conn.commit()
# Out:
# first row in the sqlite population table is ('Aruba', '1960', 54211.0)
#
# first row in the pandas Population_long dataframe is ('Aruba', '1960', 54211.0)

# %% [markdown]
# ---
# ## Part 4: Analyzing the data
# You are now ready to analyze the data. Your goal is to gain some actionable business insights to present to your boss.
#
# In this part, you should ask some questions and try to answer them based on the data. You should write SQL queries to retrieve the data. For each question, you should state why it is relevant and what you expect to find.
#
# To get you started, you should prepare answers to the following questions. You should add more questions.
# #### Who are the most profitable clients?
# Knowing which clients that generate the most revenue for the company will assist your boss in distributing customer service ressources.
#
# #### Are there any clients for which profit is declining?
# Declining profit from a specific client may indicate that the client is disatisfied with the product. Gaining a new client is often much more work than retaining one. Early warnings about declining profit may help your boss fighting customer churn.
#
#
# Remember, you are taking this to your new boss, so think about how you present the data.

# %% [markdown]
# ---
# ### Solution

# %% [markdown]
# #### <font color = "purple"> Q1: Who are the most profitable clients?<font>
# Knowing which clients that generate the most revenue for the company will assist your boss in distributing customer service ressources.

# %% [markdown]
# **To answer this question, we have defined a function `topN` to display the top N companies with the highest total profits, both in tabular and in graphical forms.**

# %%
# This function takes in an integer and return a table and a graph
def TopN(num):
        
    # SQL query to select the top N most profitable companies
    c.execute('''
    SELECT company, sum(standardized_USD) as ProfitSum
    FROM customer
    Group By company
    Order By ProfitSum DESC
    Limit ?
    ''', (num,))
    
    topN_list=c.fetchall()
    
    # consolidate the result into a pandas dataframe
    topN_df = pd.DataFrame(topN_list, columns=['company', 'total profits'])
    print("The top {} most profitable clients are:".format(num))
    print()
    
    # print the table
    print(topN_df)
    
    # helper function to decompose the topN_list obtained from the sql query
    def decomposeList(index, lst):
        return [x[index] for x in lst]
    
    # a bar plot to visualize the total profits of the top N clients in descending order
    plt.figure(figsize=(12,5))
    plt.bar(x=decomposeList(0,topN_list), height=decomposeList(1,topN_list))
    plt.title("Top {} Clients With The Largest Total Profits".format(num))
    plt.xlabel("Client Name")
    plt.xticks(rotation=45, ha="right")
    plt.ylabel("Total Profit")  
    plt.show()
    return None

# %%
# for example, show the top 5 clients with the largest total profits
TopN(5)
# Out:
# The top 5 most profitable clients are:
#
#        company  total profits
# 0   Thoughtmix   1.845760e+06
# 1  Twitterbeat   1.508610e+06
# 2     Kanoodle   1.347284e+06
# 3        Zooxo   1.132010e+06
# 4  Shufflebeat   1.047283e+06

# %%
# test again, but this time round use N=10
TopN(10)
# Out:
# The top 10 most profitable clients are:
#
#          company  total profits
# 0     Thoughtmix   1.845760e+06
# 1    Twitterbeat   1.508610e+06
# 2       Kanoodle   1.347284e+06
# 3          Zooxo   1.132010e+06
# 4    Shufflebeat   1.047283e+06
# 5  Chatterbridge   1.046740e+06
# 6          Ntags   9.579389e+05
# 7    Brainsphere   8.162344e+05
# 8       Buzzbean   8.124586e+05
# 9      Flipstorm   7.466638e+05

# %% [markdown]
# #### <font color = "purple"> Q2: Are there any clients for which profit is declining?<font>
# Declining profit from a specific client may indicate that the client is disatisfied with the product. Gaining a new client is often much more work than retaining one. Early warnings about declining profit may help your boss fighting customer churn.

# %% [markdown]
# #### Q2 Part 1: Yearly Trend

# %% [markdown]
# **The most straightforward approach is to aggregate total yearly profits of each client. We will be able to observe the trend with some visualizations.**

# %% [markdown]
# The analysis is done in three steps:
# 1. Query the database to obtain yearly profits of each client.
# 2. Plot bar graphs to achieve a more direct understanding.
# 3. Conclude on clients with declining profits.

# %%
# Query
c.execute('''
SELECT company, SUM(standardized_USD), year
FROM customer
GROUP BY company, year
''')
yearlyAggre=c.fetchall()

# %%
# function to plot the yearly sales of a single client
# this function takes in a string which is a client name and return a bar plot
def get_one_yearly_plot(name):
    
    value=[x[1] for x in list(filter(lambda x : x[0] == name, yearlyAggre))]
    year=[x[2] for x in list(filter(lambda x : x[0] == name, yearlyAggre))]

    plt.bar(x=year, height=value, color = "#cd7f7d")
    plt.xticks(year, year)
    plt.title("Yearly Sales of {}".format(name))
    plt.xlabel("Year")
    plt.ylabel("Total Sales in USD")
    plt.show()
    return None

# %%
# Example
# use this function when the boss wants to have a closer look at a particular client
get_one_yearly_plot('Lajo')

# %%
# function to plot the yearly sales of ALL clients at once
# this function does not take in any parameter and return plots for all clients
def get_all_yearly_plots():    
    fig, ax = plt.subplots(7, 4, figsize=(15,15))
    plt.subplots_adjust(wspace = 0.8, hspace = 1)
    
    for index, name in enumerate(df.company.unique()):
        
        value=[x[1] for x in list(filter(lambda x : x[0] == name, yearlyAggre))]
        year=[x[2] for x in list(filter(lambda x : x[0] == name, yearlyAggre))]
        
        row = index//4
        col = index%4
        
        ax[row, col].set_title("Yearly Sales of {}".format(name))
        ax[row, col].set_xlabel("Year")
        ax[row, col].set_ylabel("Total Sales in USD")
        ax[row, col].bar(x=year, height=value, color = "#cd7f7d")
    return None

# %%
# Example
get_all_yearly_plots()

# %% [markdown]
# **Sectional Conclusion: From the yearly trends, it can be seen that the clients with declining profits are: <font color='purple'> Flipstorm, Voomm, Zoonder, Kanoodle and Yozio</font>.**

# %% [markdown]
# #### Q2 Part 2: Monthly Trend

# %% [markdown]
# **A analytical approach can be more convincing than a visualization approach. Since there are more time steps if monthly interval is adopted, we could treat the data as a Time Series (there are only 3-4 time steps in yearly data which makes them less suitable for time series analysis). Hopefully it will shed more light on which the underperforming clients are.**

# %% [markdown]
# The analysis is done in several steps:
#
# 1. Query the database to obtain the time series of each client.
# 2. Plot the monthly sales of each client.
# 3. Calculate and plot the simple moving average sales of each client, based on its original time series.
# 4. Fit a linear line to the moving average time series. Gradient of the fitted line gives us insight into whether a client's profits is on the decline. i.e. if the gradient is negative, the profit of the client is likely to be declining.
# 5. Conclude on clients with declining profits.

# %%
# fetch data from the database
c.execute('''
SELECT company, year, month, SUM(standardized_USD)
FROM customer
GROUP BY company, year, month
''')

Time_Series=c.fetchall()

# %% [markdown]
# Define function that queries the moving average sales and the gradient of the fitted line on the moving average of different clients.

# %%
# function to get the sales of a client
# this function takes in a client name and returns the corresponding time series data
def getCompany(name):
    return list(filter(lambda x : x[0]==name, Time_Series))

# function to get the monthly moving average of the sales of a certain client
def getMA(name):
    lst = getCompany(name)
    data=[x[3] for x in lst]
    ma = bn.move_mean(data, window=3, min_count=3)
    ma = ma[2:]
    return ma

# function to get the gradient of the moving average sales. 
# This will help us understand whether the sales of a particular client is on the decline (gradient is negative)
def getGradient(name):
    lst = getCompany(name)
    lst=decomposeList(3,lst)
    m,b = np.polyfit([x for x in range(len(lst))], lst, 1)
    return m

# function to list down the gradients of the moving average sales for all companies. 
def get_all_gradients():
    grad_dict = {}
    for name in df.company.unique():
        grad_dict[name] = getGradient(name)
    return grad_dict

# %% [markdown]
# Define functions that plot the actual monthly sales and moving average monthly sales of different clients.

# %%
# function to plot the monthly sales of a client
def get_one_monthly_plot(name):
    lst = getCompany(name)
    plt.plot(decomposeList(3,lst))
    plt.title("Monthly Sales of {}".format(name))
    plt.xlabel("Month")
    plt.ylabel("Total Sales in USD")
    plt.show()

    
# function to plot the moving average of the monthly sales of a client
def get_one_monthly_MA_plot(name):
    lst = getMA(name)
    plt.plot(lst)
    plt.title("Monthly Moving Average Sales of {}".format(name))
    plt.xlabel('Month')
    plt.ylabel('Total Sales (MA) in USD')
    plt.show()


# function to plot the monthly sales of ALL clients at once
def get_all_monthly_plots():    
    fig, ax = plt.subplots(7, 4, figsize=(25,15))
    plt.subplots_adjust(wspace = 0.2, hspace = 0.7)
    
    for index, name in enumerate(df.company.unique()):
        lst = getCompany(name)
        row = index//4
        col = index%4
        ax[row, col].set_title("Monthly Sales of {}".format(name))
        ax[row, col].set_xlabel("Year")
        ax[row, col].set_ylabel("Total Sales in USD")
        ax[row, col].plot(decomposeList(3,lst))
        

# function to plot the moving average of the monthly sales of ALL clients at once
def get_all_monthly_MA_plots():    
    fig, ax = plt.subplots(7, 4, figsize=(25,15))
    plt.subplots_adjust(wspace = 0.2, hspace = 0.7)
    
    for index, name in enumerate(df.company.unique()):
        lst = getMA(name)
        row = index//4
        col = index%4      
        ax[row, col].set_title("Monthly Moving Average Sales of {}".format(name))
        ax[row, col].set_xlabel("Year")
        ax[row, col].set_ylabel("Total Sales (MA) in USD")
        ax[row, col].plot(lst)

# %% [markdown]
# Let's test it out:

# %% [markdown]
# Get the sales plot and the moving average plot of a random client:

# %%
get_one_monthly_plot("Gabtune")

# %%
get_one_monthly_MA_plot("Gabtune")

# %% [markdown]
# Get the gradient of fitted line on the moving average sales of a random company:

# %%
getGradient("Gabtune")
# Out:
# 21.223491905263124

# %% [markdown]
# Get the actual sales plots for all clients:

# %%
get_all_monthly_plots()

# %% [markdown]
# Get the moving average sales plots for all clients:

# %%
get_all_monthly_MA_plots()

# %% [markdown]
# **Sectional Conclusion: From the moving average plots, it can be seen that the clients with declining profits are: <font color='purple'> Flipstorm, Voomm and Kanoodle</font>.**

# %% [markdown]
# Get the gradients of the fitted line on moving average sales of all clients:

# %%
MA_gradients = get_all_gradients()

# %%
MA_gradients
# Out:
# {'Chatterbridge': 73.00473072380986,
#  'Lajo': -13.060374587394968,
#  'Flipstorm': -2473.295320860658,
#  'Twitterbeat': 338.08871982625493,
#  'Voomm': -910.597914936759,
#  'Buzzbean': 168.2310855159589,
#  'Zooxo': 47.542240370952435,
#  'Brainsphere': -27.96259046023168,
#  'Thoughtmix': 198.2833320366796,
#  'Wordify': 47.75640154440165,
#  'Teklist': 32.008935134491566,
#  'Avaveo': 40.9108215767053,
#  'Ntags': 22.951252164092704,
#  'Innojam': 64.41243689920951,
#  'Shufflebeat': 8.09354422007754,
#  'Zoonder': -34.19626512226513,
#  'Kanoodle': -163.94924532614112,
#  'Gabcube': 31.56877691660235,
#  'Roodel': 87.34362376525095,
#  'Riffpath': 11.295114633075922,
#  'Eimbee': 76.67344036782497,
#  'Yozio': -54.12862009626761,
#  'Rhycero': 20.511896769626773,
#  'Realpoint': 66.58886718005148,
#  'Gabtune': 21.223491905263124,
#  'Bubblemix': 138.729329487719,
#  'Gevee': -14.992198005194792,
#  'Tagtune': 59.774831648484884}

# %% [markdown]
# Find out which clients' gradients are negative, i.e. identify clients with declining profits:

# %%
# May choose a different treshold for nagativity
# Our group feels 50 means a significant decreas
Declining = list(filter(lambda x : x[1] < -50, MA_gradients.items()))
Declining
# Out:
# [('Flipstorm', -2473.295320860658),
#  ('Voomm', -910.597914936759),
#  ('Kanoodle', -163.94924532614112),
#  ('Yozio', -54.12862009626761)]

# %%
Declining_companies = list([x[0] for x in Declining])
Declining_companies
# Out:
# ['Flipstorm', 'Voomm', 'Kanoodle', 'Yozio']

# %% [markdown]
# **Sectional Conclusion: From the gradients, it can be seen that the clients with declining profits are: <font color='purple'> Flipstorm, Voomm, Kanoodle and Yozio <font>.**

# %% [markdown]
# **Overall Conclusion: From analysis above, <font color='purple'> Flipstorm, Voomm and Kanoodle </font> appear in all sectional conclusions. We identify them as clients with declining profits.**

# %% [markdown]
# #### <font color = "purple"> Q3: Why did the unprofitable clients identified in Q2 experience a decline in sales? Provide reasons to their decline.</font>
# This question falls in the realm of prescriptive analysis where we seek to identify the reasons behind such decline. Identifying the underlying reasons provides actionable insights into how to reverse the declining trend, as well as how to prevent such incidents from happening in the future. This will be valuable to the company in the long run.
#
# In this question, we will focus on clients identified in Q2. We try to incorporate the external data (GDP and population) sourced in section 2, and explore its relationship with the declining clients.

# %%
# fetch one company's yearly sales and the corresponding GDP & population in the company's home country
def get_one_sales_GDP_population(name): 

    c.execute('''
    SELECT c.company, SUM(c.standardized_USD), c.year, gdp.country, gdp.value, population.value
    FROM customer as c
    LEFT JOIN gdp
    On c.country = gdp.country AND c.year = gdp.year
    LEFT JOIN population
    ON c.country = population.country AND c.year= population.year
    Where company = ?
    GROUP BY company, c.year
    ''', (name,))
    
    lst = c.fetchall()
    return lst


# fetch ALL companies' yearly sales and the corresponding GDP & population in each company's home country
def get_multiple_sales_GDP_population(names):
    # INPUT ARGUMENT names: a list of strings containing the company names that are of interest
    lst = []
    for client in names:
        new_lst = get_one_sales_GDP_population(client)
        lst.append(new_lst)
    return lst

# %% [markdown]
# Let's test it out:

# %%
# get the corresponding yearly sales, GDP and population of a client, Lajo
get_one_sales_GDP_population("Lajo")
# Out:
# [('Lajo', 50737.16349899999, 2016, 'Greece', 195222000000.0, 10775971.0),
#  ('Lajo', 41146.140186, 2017, 'Greece', 203086000000.0, 10754679.0),
#  ('Lajo', 47082.81379600002, 2018, 'Greece', 218032000000.0, 10727668.0)]

# %%
# get the corresponding yearly sales, GDP and population of the declining clients identified in Qn2
get_multiple_sales_GDP_population(Declining_companies)
# Out:
# [[('Flipstorm', 641350.7544590005, 2016, 'Greece', 195222000000.0, 10775971.0),
#   ('Flipstorm', 91601.54159000004, 2017, 'Greece', 203086000000.0, 10754679.0),
#   ('Flipstorm', 12361.454862, 2018, 'Greece', 218032000000.0, 10727668.0),
#   ('Flipstorm', 1350.0662879999998, 2019, None, None, None)],
#  [('Voomm', 141625.99449399996, 2016, 'France', 2471290000000.0, 66859768.0),
#   ('Voomm', 17141.994736, 2017, 'France', 2586290000000.0, 66865144.0),
#   ('Voomm', 2111.249652, 2018, 'France', 2777540000000.0, 66987244.0)],
#  [('Kanoodle', 500526.7224075931, 2016, 'Japan', 4926670000000.0, 126994511.0),
#   ('Kanoodle',
#    482435.26812154154,
#    2017,
#    'Japan',
#    4859950000000.0,
#    126785797.0),
#   ('Kanoodle',
#    364321.6503773853,
#    2018,
#    'Japan',
#    4970920000000.0,
#    126529100.0)],
#  [('Yozio', 148407.117236, 2016, 'Greece', 195222000000.0, 10775971.0),
#   ('Yozio', 139767.79223399993, 2017, 'Greece', 203086000000.0, 10754679.0),
#   ('Yozio', 128742.72850200004, 2018, 'Greece', 218032000000.0, 10727668.0)]]

# %%
# function to plot the yearly sales of a client and the corresponding GDP, population of the client's country of origin
def plot_one_sales_GDP_population(name):
    
    lst = get_one_sales_GDP_population(name)   
    sales = list(map(lambda x:x[1], lst))
    year = list(map(lambda x:x[2], lst))
    country = list(map(lambda x:x[3], lst))
    gdp = list(map(lambda x:x[4], lst))
    population = list(map(lambda x:x[5], lst))
        
    fig, ax = plt.subplots(1, 3, figsize=(15,1), sharex = True)
    plt.subplots_adjust(wspace = 0.4, hspace = 1.5)
    plt.xticks(year, year)
    
    # generate a random color from the colormap "viridis"
    cmap = plt.get_cmap('viridis')
    colors = cmap(np.linspace(0, 1, 15))
    rand_color = list(random.choice(colors))
    
    ax[0].plot(year, sales, color=rand_color)
    ax[1].plot(year, gdp, color=rand_color)
    ax[2].plot(year, population, color=rand_color)

    ax[0].set_ylabel("Total Sales in USD")
    ax[1].set_ylabel("GDP")
    ax[2].set_ylabel("Population")
        
    ax[0].set_title("Sales of {}".format(name))
    ax[1].set_title("GDP of {}".format(country[0]))
    ax[2].set_title("Population of {}".format(country[0]))

# %%
# function to plot the yearly sales of multiple clients and the corresponding GDP, population of their countries of origin
def plot_multiple_sales_GDP_population(names):
    for name in names:
        plot_one_sales_GDP_population(name)

# %% [markdown]
# let's test it out:

# %%
# plot the relevant information of Flipstorm
plot_one_sales_GDP_population("Flipstorm")

# %%
# plot the relevant information of all declining companies
plot_multiple_sales_GDP_population(Declining_companies)

# %% [markdown]
# **Conclusion: It can be seen that while sales of the clients are declining, GDP of these clients' countries are on the rise and populations are on the decline. We can conclude that population and profit often have a positive association while GDP and profit have a negative association. <font color='purple'> However, association does not imply causation so we cannot conclude anything on the causal relationship</font>.**

# %%
# ## get ts list for plotting
# def creatTimeSeries(lst, year_index, month_index):
#     def helper(index):
#         date = datetime.datetime.strptime(
#             str(lst[index][year_index]) + "-" + str(lst[index][month_index]),
#             "%Y-%m")
#         return date
#     return [helper(x) for x in range(len(lst))]

# %% [markdown]
# #### <font color = "purple"> Q4: Which clients have lower risks than the rest? </font>

# %% [markdown]
# **To define low risk, our group would like to define two indicator:**
# 1. Risk_Count_Fraction = Number of negative profit occurrence / Number of postive profit occurrence
# 2. Risk_Amount_Fraction = Total negative profit (loss) / Total positive profit

# %%
# Query Nagetive Profits
c.execute('''
SELECT company, COUNT(*) as counts, SUM(standardized_USD)
FROM customer
Where standardized_USD < 0
GROUP BY company
ORDER BY company
''')

negative=c.fetchall()

# %%
# Query Positive Profits
c.execute('''
SELECT company, COUNT(*) as counts, SUM(standardized_USD)
FROM customer
Where standardized_USD > 0
GROUP BY company
ORDER BY company
''')

positive=c.fetchall()

# %%
def get_Fractions():
    res=[]
    nagetive_name_list=[x[0] for x in negative]
    
    for record in positive:
        name = record[0]
        positive_count=record[1]
        positive_profit=record[2]
        if name not in nagetive_name_list:
            negative_count = 0
            negative_profit = 0
        else:
            index=nagetive_name_list.index(name)
            negative_count = negative[index][1]
            negative_profit = abs(negative[index][2])
        res.append([name,
                    negative_count/positive_count,
                    negative_profit/positive_profit])
    return res

# %%
# the first element is client name
# the second is risk_count_fraction 
# the last is risk_amount_fraction
risk=get_Risk_Count_Fraction()
risk
# Out:
# [['Avaveo', 0.0, 0.0],
#  ['Brainsphere', 0.32441200324412006, 0.051575426404727766],
#  ['Bubblemix', 3.8461538461538463, 0.4699271979062853],
#  ['Buzzbean', 0.32076984763432237, 0.0483277528512471],
#  ['Chatterbridge', 0.44303797468354433, 0.09802447504396329],
#  ['Eimbee', 0.4032258064516129, 0.04290167930367253],
#  ['Flipstorm', 0.42122999157540014, 0.0649728276810013],
#  ['Gabcube', 0.28169014084507044, 0.024897275607064697],
#  ['Gabtune', 0.0, 0.0],
#  ['Gevee', 0.0, 0.0],
#  ['Innojam', 0.0, 0.0],
#  ['Kanoodle', 1.6129032258064515, 0.2021279811247624],
#  ['Lajo', 0.0, 0.0],
#  ['Ntags', 0.26595744680851063, 0.07150702160616229],
#  ['Realpoint', 0.0, 0.0],
#  ['Rhycero', 0.9900990099009901, 0.18864884846687102],
#  ['Riffpath', 0.0, 0.0],
#  ['Roodel', 0.16025641025641024, 0.004731188894765143],
#  ['Shufflebeat', 0.38885288399222295, 0.05690860304486575],
#  ['Tagtune', 0.0, 0.0],
#  ['Teklist', 0.0, 0.0],
#  ['Thoughtmix', 0.3606202668589975, 0.06958460045972119],
#  ['Twitterbeat', 0.3546099290780142, 0.023757481617346657],
#  ['Voomm', 0.0, 0.0],
#  ['Wordify', 0.4158004158004158, 0.04960216034981814],
#  ['Yozio', 0.30816640986132515, 0.08357225648523],
#  ['Zoonder', 0.4444444444444444, 0.043716343862062766],
#  ['Zooxo', 0.421179302045728, 0.13845192965767494]]

# %%
# function takes in an integer and returns top N top risky client by risk_count_fraction
def TopN_risky_count(N):
    return sorted(risk, key=lambda x : x[1], reverse = True)[:N]

# function takes in an integer and returns top N top risky client by risk_amount_fraction
def TopN_risky_amount(N):
    return sorted(risk, key=lambda x : x[2], reverse = True)[:N]

# %%
# let's try top 5
TopN_risky_count(5)
# Out:
# [['Bubblemix', 3.8461538461538463, 0.4699271979062853],
#  ['Kanoodle', 1.6129032258064515, 0.2021279811247624],
#  ['Rhycero', 0.9900990099009901, 0.18864884846687102],
#  ['Zoonder', 0.4444444444444444, 0.043716343862062766],
#  ['Chatterbridge', 0.44303797468354433, 0.09802447504396329]]

# %%
# let's try top 5
TopN_risky_amount(5)
# Out:
# [['Bubblemix', 3.8461538461538463, 0.4699271979062853],
#  ['Kanoodle', 1.6129032258064515, 0.2021279811247624],
#  ['Rhycero', 0.9900990099009901, 0.18864884846687102],
#  ['Zooxo', 0.421179302045728, 0.13845192965767494],
#  ['Chatterbridge', 0.44303797468354433, 0.09802447504396329]]

# %% [markdown]
# ---
# ## Part 5: Performance
# Your boss is very impressed with what you have achieved in less than two weeks, and he would like to take your idea of storing the customer and sales data in a relational database to production. However, John is concerned that the solution will not scale. His experience is telling him that you will see many occurrences of the following queries.
#
# - Show all sales to company X between time $t_1$ and time $t_2$
# - Show the latest X sales in the database
# - Show total sales per company per day
#
# Show that Johns concern is not justified.

# %% [markdown]
# ---
# ### Solution

# %%
df.columns
# Out:
# Index(['key', 'part', 'company', 'country', 'city', 'price', 'date',
#        'currency_name', 'price_amount', 'currency_symbol',
#        'exchange_rate_to_USD', 'standardized_USD', 'year', 'month'],
#       dtype='object')

# %%
def betweenTime(Company,T_start,T_end):
    substitution=(Company,T_start,T_end)
    
    c.execute('''
    SELECT part, company, country, city, date, price, standardized_USD
    FROM customer 
    Where company = ? AND date Between ? AND ? 
    ''', substitution)
    
    return c.fetchall()

# %%
betweenTime('Chatterbridge','2016-01-02','2016-01-03')
# Out:
# [('54868-5165',
#   'Chatterbridge',
#   'Spain',
#   'Barcelona',
#   '2016-01-02 00:01:05',
#   '784.79€',
#   854.4008729999999),
#  ('44946-1046',
#   'Chatterbridge',
#   'Spain',
#   'Barcelona',
#   '2016-01-02 04:51:55',
#   '412.55€',
#   449.143185),
#  ('16729-167',
#   'Chatterbridge',
#   'Spain',
#   'Barcelona',
#   '2016-01-02 07:20:59',
#   '359.52€',
#   391.409424)]

# %%
def latest(x):
    substitution=(x,)
    
    c.execute('''
    SELECT part, company, country, city, date, price, standardized_USD
    FROM customer 
    Order BY date DESC
    LIMIT ?
    ''', substitution)
    
    return c.fetchall()

# %%
latest(5)
# Out:
# [('43419-018',
#   'Flipstorm',
#   'Greece',
#   'Athens',
#   '2019-05-14 22:48:39',
#   '139.56€',
#   156.67005600000002),
#  ('49288-0285',
#   'Flipstorm',
#   'Greece',
#   'Athens',
#   '2019-02-21 20:05:00',
#   '1051.08€',
#   1193.3962319999998),
#  ('52343-025',
#   'Brainsphere',
#   'Portugal',
#   'Braga',
#   '2018-12-31 21:38:02',
#   '686.1€',
#   785.5845),
#  ('49999-737',
#   'Thoughtmix',
#   'Portugal',
#   'Amadora',
#   '2018-12-31 21:24:17',
#   '828.37€',
#   948.48365),
#  ('21695-267',
#   'Roodel',
#   'Portugal',
#   'Aranhas',
#   '2018-12-31 20:48:14',
#   '606.37€',
#   694.2936500000001)]

# %%
def salePerCompanyPerDay():
    
    c.execute('''
    SELECT company, DATE(date) , SUM(standardized_USD)
    FROM customer 
    Group BY company, Date(date)
    ''')
    
    return c.fetchall()

# %%
salePerCompanyPerDay()
# Out:
# [('Avaveo', '2016-01-03', 1121.2739040000001),
#  ('Avaveo', '2016-01-06', 738.652146),
#  ('Avaveo', '2016-01-18', 390.43463199999997),
#  ('Avaveo', '2016-01-19', 515.52358),
#  ('Avaveo', '2016-02-01', 150.645444),
#  ('Avaveo', '2016-02-11', 831.723753),
#  ('Avaveo', '2016-02-20', 833.165352),
#  ('Avaveo', '2016-03-07', 420.387093),
#  ('Avaveo', '2016-03-08', 969.0193320000001),
#  ('Avaveo', '2016-03-18', 563.1604699999999),
#  ('Avaveo', '2016-03-20', 185.336528),
#  ('Avaveo', '2016-03-22', 965.330776),
#  ('Avaveo', '2016-04-02', 410.831784),
#  ('Avaveo', '2016-04-12', 530.210296),
#  ('Avaveo', '2016-04-13', 1854.3746339999998),
#  ('Avaveo', '2016-04-14', 519.22354),
#  ('Avaveo', '2016-04-18', 723.75359),
#  ('Avaveo', '2016-05-10', 117.333125),
#  ('Avaveo', '2016-05-12', 1147.134247),
#  ('Avaveo', '2016-05-13', 525.616664),
#  ('Avaveo', '2016-05-20', 1357.3307149999998),
#  ('Avaveo', '2016-05-27', 187.410208),
#  ('Avaveo', '2016-06-11', 1171.015272),
#  ('Avaveo', '2016-06-16', 964.271504),
#  ('Avaveo', '2016-07-03', 847.6852799999999),
#  ('Avaveo', '2016-07-08', 819.05823),
#  ('Avaveo', '2016-07-10', 896.2936199999999),
#  ('Avaveo', '2016-07-17', 157.96195999999998),
#  ('Avaveo', '2016-07-20', 1275.3714779999998),
#  ('Avaveo', '2016-07-25', 992.11388),
#  ('Avaveo', '2016-07-29', 347.87023899999997),
#  ('Avaveo', '2016-08-26', 1118.21805),
#  ('Avaveo', '2016-08-27', 229.97729999999999),
#  ('Avaveo', '2016-09-05', 516.890948),
#  ('Avaveo', '2016-09-08', 580.2416319999999),
#  ('Avaveo', '2016-09-11', 509.978412),
#  ('Avaveo', '2016-09-13', 348.47704799999997),
#  ('Avaveo', '2016-09-18', 1586.7726480000001),
#  ('Avaveo', '2016-09-26', 166.38478800000001),
#  ('Avaveo', '2016-09-27', 1103.9919000000002),
#  ('Avaveo', '2016-09-30', 912.4117500000001),
#  ('Avaveo', '2016-10-02', 182.48235000000003),
#  ('Avaveo', '2016-10-17', 872.20899),
#  ('Avaveo', '2016-10-20', 553.73238),
#  ('Avaveo', '2016-10-23', 491.08923200000004),
#  ('Avaveo', '2016-10-26', 799.6663000000001),
#  ('Avaveo', '2016-10-30', 1023.28218),
#  ('Avaveo', '2016-10-31', 129.08617800000002),
#  ('Avaveo', '2016-11-02', 1111.9409),
#  ('Avaveo', '2016-11-05', 777.597114),
#  ('Avaveo', '2016-11-09', 474.64038600000003),
#  ('Avaveo', '2016-11-14', 190.11705700000002),
#  ('Avaveo', '2016-11-17', 592.4571940000001),
#  ('Avaveo', '2016-11-18', 955.0050209999999),
#  ('Avaveo', '2016-11-23', 400.554162),
#  ('Avaveo', '2016-11-24', 316.83027599999997),
#  ('Avaveo', '2016-11-25', 650.2746559999999),
#  ('Avaveo', '2016-11-28', 116.75387599999999),
#  ('Avaveo', '2016-11-30', 940.4849549999999),
#  ('Avaveo', '2016-12-04', 431.714014),
#  ('Avaveo', '2016-12-11', 949.8770810000001),
#  ('Avaveo', '2016-12-16', 154.36149300000002),
#  ('Avaveo', '2016-12-24', 914.557746),
#  ('Avaveo', '2016-12-30', 231.81767200000002),
#  ('Avaveo', '2017-01-01', 1242.098735),
#  ('Avaveo', '2017-01-09', 26.594964),
#  ('Avaveo', '2017-01-13', 1636.3995340000001),
#  ('Avaveo', '2017-01-15', 1046.8782170000002),
#  ('Avaveo', '2017-01-17', 208.305948),
#  ('Avaveo', '2017-01-27', 142.32432500000002),
#  ('Avaveo', '2017-02-07', 484.506225),
#  ('Avaveo', '2017-02-11', 370.611972),
#  ('Avaveo', '2017-02-13', 617.4704969999999),
#  ('Avaveo', '2017-02-15', 717.8561050000001),
#  ('Avaveo', '2017-02-18', 635.7091499999999),
#  ('Avaveo', '2017-02-22', 538.2971389999999),
#  ('Avaveo', '2017-03-18', 383.48269200000004),
#  ('Avaveo', '2017-03-26', 907.53356),
#  ('Avaveo', '2017-03-27', 508.668746),
#  ('Avaveo', '2017-03-29', 133.479412),
#  ('Avaveo', '2017-04-01', 1425.623468),
#  ('Avaveo', '2017-04-16', 735.1708),
#  ('Avaveo', '2017-04-18', 1138.829384),
#  ('Avaveo', '2017-04-21', 879.4504860000001),
#  ('Avaveo', '2017-04-23', 1024.9860780000001),
#  ('Avaveo', '2017-04-25', 517.082898),
#  ('Avaveo', '2017-04-27', 1403.97543),
#  ('Avaveo', '2017-05-05', 28.399951),
#  ('Avaveo', '2017-05-14', 269.800932),
#  ('Avaveo', '2017-05-16', 235.26916600000004),
#  ('Avaveo', '2017-05-21', 768.22088),
#  ('Avaveo', '2017-05-22', 939.139033),
#  ('Avaveo', '2017-06-03', 309.06200099999995),
#  ('Avaveo', '2017-06-05', 705.627272),
#  ('Avaveo', '2017-06-14', 384.37493000000006),
#  ('Avaveo', '2017-06-15', 329.67615),
#  ('Avaveo', '2017-06-24', 1609.0460759999999),
#  ('Avaveo', '2017-06-29', 438.27061299999997),
#  ('Avaveo', '2017-07-15', 1219.133415),
#  ('Avaveo', '2017-07-16', 872.5511849999999),
#  ('Avaveo', '2017-07-17', 981.8119960000001),
#  ('Avaveo', '2017-07-26', 469.066896),
#  ('Avaveo', '2017-07-29', 1069.743445),
#  ('Avaveo', '2017-07-31', 252.48231000000004),
#  ('Avaveo', '2017-08-03', 859.23328),
#  ('Avaveo', '2017-08-05', 532.089912),
#  ('Avaveo', '2017-08-19', 1102.17468),
#  ('Avaveo', '2017-08-28', 315.976725),
#  ('Avaveo', '2017-08-30', 2061.468),
#  ('Avaveo', '2017-09-10', 770.32044),
#  ('Avaveo', '2017-09-21', 1059.09261),
#  ('Avaveo', '2017-09-27', 1860.8897949999998),
#  ('Avaveo', '2017-10-10', 176.44772899999998),
#  ('Avaveo', '2017-10-14', 181.86219000000003),
#  ('Avaveo', '2017-10-22', 678.7195579999999),
#  ('Avaveo', '2017-10-27', 1885.3599050000003),
#  ('Avaveo', '2017-10-31', 491.868432),
#  ('Avaveo', '2017-11-13', 744.142352),
#  ('Avaveo', '2017-12-02', 278.952835),
#  ('Avaveo', '2017-12-05', 1289.1076110000001),
#  ('Avaveo', '2017-12-10', 543.314082),
#  ('Avaveo', '2017-12-12', 1126.2297540000002),
#  ('Avaveo', '2017-12-21', 1393.8594239999998),
#  ('Avaveo', '2017-12-22', 1116.102186),
#  ('Avaveo', '2017-12-26', 1975.586922),
#  ('Avaveo', '2017-12-28', 1302.345486),
#  ('Avaveo', '2017-12-29', 958.96028),
#  ('Avaveo', '2018-01-01', 323.822993),
#  ('Avaveo', '2018-01-04', 548.61968),
#  ('Avaveo', '2018-01-15', 1037.885303),
#  ('Avaveo', '2018-01-20', 306.54657),
#  ('Avaveo', '2018-01-30', 653.5184939999999),
#  ('Avaveo', '2018-02-05', 706.8283600000001),
#  ('Avaveo', '2018-02-15', 161.984238),
#  ('Avaveo', '2018-02-26', 3259.8104),
#  ('Avaveo', '2018-03-05', 119.03330399999999),
#  ('Avaveo', '2018-03-09', 417.26715900000005),
#  ('Avaveo', '2018-03-15', 1053.3043499999999),
#  ('Avaveo', '2018-03-19', 753.18771),
#  ('Avaveo', '2018-03-23', 272.35276),
#  ('Avaveo', '2018-03-27', 473.81516000000005),
#  ('Avaveo', '2018-03-28', 1987.201032),
#  ('Avaveo', '2018-04-07', 205.65354),
#  ('Avaveo', '2018-04-24', 1019.748861),
#  ('Avaveo', '2018-04-29', 922.7756400000001),
#  ('Avaveo', '2018-05-02', 493.27157400000004),
#  ('Avaveo', '2018-05-13', 960.651198),
#  ('Avaveo', '2018-05-18', 1151.039043),
#  ('Avaveo', '2018-05-20', 657.474048),
#  ('Avaveo', '2018-05-31', 822.229118),
#  ('Avaveo', '2018-06-01', 445.54575800000003),
#  ('Avaveo', '2018-06-03', 323.616377),
#  ('Avaveo', '2018-06-04', 692.471263),
#  ('Avaveo', '2018-06-08', 1053.80487),
#  ('Avaveo', '2018-06-11', 840.2025600000001),
#  ('Avaveo', '2018-06-19', 507.96889400000003),
#  ('Avaveo', '2018-06-23', 309.266048),
#  ('Avaveo', '2018-06-27', 203.77948800000001),
#  ('Avaveo', '2018-06-29', 59.898804),
#  ('Avaveo', '2018-07-06', 358.87164000000007),
#  ('Avaveo', '2018-07-08', 441.53756400000003),
#  ('Avaveo', '2018-07-09', 1964.8608410000002),
#  ('Avaveo', '2018-07-22', 447.3111),
#  ('Avaveo', '2018-07-25', 856.84193),
#  ('Avaveo', '2018-07-27', 985.579125),
#  ('Avaveo', '2018-07-31', 451.836),
#  ('Avaveo', '2018-08-10', 953.929664),
#  ('Avaveo', '2018-08-11', 886.86624),
#  ('Avaveo', '2018-08-22', 124.895232),
#  ('Avaveo', '2018-08-23', 368.10798900000003),
#  ('Avaveo', '2018-08-31', 1033.047566),
#  ('Avaveo', '2018-09-04', 251.42725199999998),
#  ('Avaveo', '2018-09-14', 803.26808),
#  ('Avaveo', '2018-09-17', 1113.891911),
#  ('Avaveo', '2018-09-19', 2099.581653),
#  ('Avaveo', '2018-09-25', 574.152304),
#  ('Avaveo', '2018-09-30', 1067.07568),
#  ('Avaveo', '2018-10-01', 1051.352722),
#  ('Avaveo', '2018-10-07', 472.58593800000006),
#  ('Avaveo', '2018-10-08', 535.16175),
#  ('Avaveo', '2018-10-11', 586.100125),
#  ('Avaveo', '2018-10-22', 246.45434799999998),
#  ('Avaveo', '2018-10-27', 802.012085),
#  ('Avaveo', '2018-10-28', 929.6093000000001),
#  ('Avaveo', '2018-11-01', 1069.244443),
#  ('Avaveo', '2018-11-04', 222.916925),
#  ('Avaveo', '2018-11-06', 1289.9812120000001),
#  ('Avaveo', '2018-11-12', 1379.17395),
#  ('Avaveo', '2018-11-13', 830.0257880000001),
#  ('Avaveo', '2018-11-29', 1305.9522560000003),
#  ('Avaveo', '2018-11-30', 586.91953),
#  ('Avaveo', '2018-12-03', 864.80158),
#  ('Avaveo', '2018-12-06', 997.423721),
#  ('Avaveo', '2018-12-20', 243.253593),
#  ('Brainsphere', '2016-01-02', 1556.046249),
#  ('Brainsphere', '2016-01-04', 1033.500932),
#  ('Brainsphere', '2016-01-05', 567.947592),
#  ('Brainsphere', '2016-01-06', 1016.869946),
#  ('Brainsphere', '2016-01-07', 1283.771632),
#  ('Brainsphere', '2016-01-08', 574.1884870000001),
#  ('Brainsphere', '2016-01-09', 1209.48096),
#  ('Brainsphere', '2016-01-10', 350.821161),
#  ('Brainsphere', '2016-01-11', 1705.093464),
#  ('Brainsphere', '2016-01-12', 642.921552),
#  ('Brainsphere', '2016-01-14', 386.668821),
#  ('Brainsphere', '2016-01-15', 2136.4918979999998),
#  ('Brainsphere', '2016-01-17', 1930.7302559999998),
#  ('Brainsphere', '2016-01-19', 743.545088),
#  ('Brainsphere', '2016-01-20', 1594.876075),
#  ('Brainsphere', '2016-01-21', 1120.584696),
#  ('Brainsphere', '2016-01-22', 1019.551064),
#  ('Brainsphere', '2016-01-23', 990.131688),
#  ('Brainsphere', '2016-01-24', 1245.967856),
#  ('Brainsphere', '2016-01-26', 1814.969923),
#  ('Brainsphere', '2016-01-27', 1445.5453200000002),
#  ('Brainsphere', '2016-01-28', 1179.955369),
#  ('Brainsphere', '2016-01-30', 526.42044),
#  ('Brainsphere', '2016-01-31', 882.51072),
#  ('Brainsphere', '2016-02-01', 602.7994560000001),
#  ('Brainsphere', '2016-02-02', 1435.9140140000002),
#  ('Brainsphere', '2016-02-04', 582.398232),
#  ('Brainsphere', '2016-02-05', 208.256382),
#  ('Brainsphere', '2016-02-06', 443.5095840000001),
#  ('Brainsphere', '2016-02-08', 1023.001554),
#  ('Brainsphere', '2016-02-09', 2318.537364),
#  ('Brainsphere', '2016-02-10', 823.866059),
#  ('Brainsphere', '2016-02-11', 542.431988),
#  ('Brainsphere', '2016-02-12', 653.25095),
#  ('Brainsphere', '2016-02-15', 793.23218),
#  ('Brainsphere', '2016-02-16', 1051.848366),
#  ('Brainsphere', '2016-02-18', 825.824504),
#  ('Brainsphere', '2016-02-19', 1337.7781439999999),
#  ('Brainsphere', '2016-02-22', 1357.68651),
#  ('Brainsphere', '2016-02-24', 1597.395089),
#  ('Brainsphere', '2016-02-26', 1521.788614),
#  ('Brainsphere', '2016-02-28', 350.078848),
#  ('Brainsphere', '2016-02-29', 210.508592),
#  ('Brainsphere', '2016-03-01', 256.14432),
#  ('Brainsphere', '2016-03-02', 1818.7165359999997),
#  ('Brainsphere', '2016-03-03', 302.52455199999997),
#  ('Brainsphere', '2016-03-04', 2447.75804),
#  ('Brainsphere', '2016-03-05', 2327.40617),
#  ('Brainsphere', '2016-03-06', 2831.58737),
#  ('Brainsphere', '2016-03-09', 296.995218),
#  ('Brainsphere', '2016-03-10', 972.7112010000001),
#  ('Brainsphere', '2016-03-14', 1200.9298330000001),
#  ('Brainsphere', '2016-03-15', 703.3996619999999),
#  ('Brainsphere', '2016-03-16', 384.60676800000005),
#  ('Brainsphere', '2016-03-17', 306.539411),
#  ('Brainsphere', '2016-03-19', 1200.7285029999998),
#  ('Brainsphere', '2016-03-21', 404.865591),
#  ('Brainsphere', '2016-03-22', 1043.534476),
#  ('Brainsphere', '2016-03-23', 443.745633),
#  ('Brainsphere', '2016-03-25', 1286.825826),
#  ('Brainsphere', '2016-03-26', 880.27368),
#  ('Brainsphere', '2016-03-27', 632.87796),
#  ('Brainsphere', '2016-03-28', 343.71050999999994),
#  ('Brainsphere', '2016-03-29', 322.028992),
#  ('Brainsphere', '2016-03-30', 763.3621640000001),
#  ('Brainsphere', '2016-04-01', 281.192904),
#  ('Brainsphere', '2016-04-02', 2290.389768),
#  ('Brainsphere', '2016-04-05', 1130.0844060000002),
#  ('Brainsphere', '2016-04-06', 760.41888),
#  ('Brainsphere', '2016-04-07', 1244.051172),
#  ('Brainsphere', '2016-04-08', 769.16147),
#  ('Brainsphere', '2016-04-10', 448.15672),
#  ('Brainsphere', '2016-04-11', 1095.718),
#  ('Brainsphere', '2016-04-13', 1983.262218),
#  ('Brainsphere', '2016-04-16', 534.590784),
#  ('Brainsphere', '2016-04-18', 879.222396),
#  ('Brainsphere', '2016-04-19', 2299.7819070000005),
#  ('Brainsphere', '2016-04-21', 1476.5474249999997),
#  ('Brainsphere', '2016-04-22', 540.0608500000001),
#  ('Brainsphere', '2016-04-24', 3108.148743),
#  ('Brainsphere', '2016-04-25', 2281.489408),
#  ('Brainsphere', '2016-04-26', 2368.6785330000002),
#  ('Brainsphere', '2016-04-27', 812.9908810000001),
#  ('Brainsphere', '2016-04-28', 1477.1646899999998),
#  ('Brainsphere', '2016-04-29', 582.887151),
#  ('Brainsphere', '2016-05-02', 562.685787),
#  ('Brainsphere', '2016-05-03', 366.297678),
#  ('Brainsphere', '2016-05-04', 1519.568895),
#  ('Brainsphere', '2016-05-05', 962.47746),
#  ('Brainsphere', '2016-05-06', 3099.9394140000004),
#  ('Brainsphere', '2016-05-07', 648.653655),
#  ('Brainsphere', '2016-05-09', 1028.12527),
#  ('Brainsphere', '2016-05-10', 561.8567499999999),
#  ('Brainsphere', '2016-05-11', 467.83745400000004),
#  ('Brainsphere', '2016-05-13', 619.5440600000001),
#  ('Brainsphere', '2016-05-15', 1930.4082799999999),
#  ('Brainsphere', '2016-05-16', 1695.2933920000003),
#  ('Brainsphere', '2016-05-17', 1641.7324899999999),
#  ('Brainsphere', '2016-05-20', 930.2233849999999),
#  ('Brainsphere', '2016-05-21', 135.996718),
#  ('Brainsphere', '2016-05-23', 614.96331),
#  ('Brainsphere', '2016-05-24', 777.8512000000001),
#  ('Brainsphere', '2016-05-26', 197.50608),
#  ('Brainsphere', '2016-05-27', 1131.519424),
#  ('Brainsphere', '2016-05-28', 343.36016),
#  ('Brainsphere', '2016-05-29', 971.537824),
#  ('Brainsphere', '2016-05-30', 1580.2676519999998),
#  ('Brainsphere', '2016-05-31', 842.863164),
#  ('Brainsphere', '2016-06-01', 1349.8192),
#  ('Brainsphere', '2016-06-03', 2978.5864679999995),
#  ('Brainsphere', '2016-06-05', 1212.7409579999999),
#  ('Brainsphere', '2016-06-06', 1663.6385609999998),
#  ('Brainsphere', '2016-06-07', 1490.922936),
#  ('Brainsphere', '2016-06-08', 557.3740859999999),
#  ('Brainsphere', '2016-06-10', 852.7624560000002),
#  ('Brainsphere', '2016-06-13', 2381.119956),
#  ('Brainsphere', '2016-06-14', 1123.7572),
#  ('Brainsphere', '2016-06-16', 473.967558),
#  ('Brainsphere', '2016-06-17', 425.78383599999995),
#  ('Brainsphere', '2016-06-18', 211.991598),
#  ('Brainsphere', '2016-06-19', 1357.772592),
#  ('Brainsphere', '2016-06-20', 1519.201916),
#  ('Brainsphere', '2016-06-21', 530.275866),
#  ('Brainsphere', '2016-06-22', 2586.4133730000003),
#  ('Brainsphere', '2016-06-24', 655.062936),
#  ('Brainsphere', '2016-06-25', 994.202638),
#  ('Brainsphere', '2016-06-26', 257.594348),
#  ('Brainsphere', '2016-06-27', 1131.6942000000001),
#  ('Brainsphere', '2016-07-01', 452.53753499999993),
#  ('Brainsphere', '2016-07-02', 919.4614899999999),
#  ('Brainsphere', '2016-07-03', 1053.2262449999998),
#  ('Brainsphere', '2016-07-04', 1223.0080899999998),
#  ('Brainsphere', '2016-07-05', 2498.4093380000004),
#  ('Brainsphere', '2016-07-06', 1791.318408),
#  ('Brainsphere', '2016-07-07', 210.81916000000004),
#  ('Brainsphere', '2016-07-09', 1431.2070899999999),
#  ('Brainsphere', '2016-07-10', 1999.54089),
#  ('Brainsphere', '2016-07-12', 2002.915716),
#  ('Brainsphere', '2016-07-13', 952.0369919999999),
#  ('Brainsphere', '2016-07-14', 1282.3074809999998),
#  ('Brainsphere', '2016-07-15', 914.176328),
#  ('Brainsphere', '2016-07-20', 343.748769),
#  ('Brainsphere', '2016-07-21', 915.65492),
#  ('Brainsphere', '2016-07-22', 3506.8245579999993),
#  ('Brainsphere', '2016-07-23', 1048.896262),
#  ('Brainsphere', '2016-07-24', 1557.7650899999999),
#  ('Brainsphere', '2016-07-25', 943.1561240000001),
#  ('Brainsphere', '2016-07-26', 1079.6304749999997),
#  ('Brainsphere', '2016-07-31', 1246.823035),
#  ('Brainsphere', '2016-08-02', 125.71977599999998),
#  ('Brainsphere', '2016-08-03', 1465.2400000000002),
#  ('Brainsphere', '2016-08-04', 874.710528),
#  ('Brainsphere', '2016-08-06', 2290.806508),
#  ('Brainsphere', '2016-08-08', 1218.294995),
#  ('Brainsphere', '2016-08-09', 140.08131),
#  ('Brainsphere', '2016-08-11', 344.86191299999996),
#  ('Brainsphere', '2016-08-13', 1767.6168859999998),
#  ('Brainsphere', '2016-08-14', 1505.43736),
#  ('Brainsphere', '2016-08-16', 1199.201445),
#  ('Brainsphere', '2016-08-17', 585.4273679999999),
#  ('Brainsphere', '2016-08-18', 106.949487),
#  ('Brainsphere', '2016-08-19', 2006.1177500000001),
#  ('Brainsphere', '2016-08-22', 738.033068),
#  ('Brainsphere', '2016-08-23', 1221.754572),
#  ('Brainsphere', '2016-08-24', 1903.67226),
#  ('Brainsphere', '2016-08-25', 1078.22887),
#  ('Brainsphere', '2016-08-26', 1847.1569000000002),
#  ('Brainsphere', '2016-08-28', 1207.7251700000002),
#  ('Brainsphere', '2016-08-30', 889.039808),
#  ('Brainsphere', '2016-09-01', 616.864224),
#  ('Brainsphere', '2016-09-03', 402.332385),
#  ('Brainsphere', '2016-09-04', 2462.392842),
#  ('Brainsphere', '2016-09-05', 1369.042008),
#  ('Brainsphere', '2016-09-06', 385.833584),
#  ('Brainsphere', '2016-09-08', 633.5022720000001),
#  ('Brainsphere', '2016-09-09', 133.63848),
#  ('Brainsphere', '2016-09-13', 878.8068390000001),
#  ('Brainsphere', '2016-09-15', 817.287988),
#  ('Brainsphere', '2016-09-16', 164.15779799999999),
#  ('Brainsphere', '2016-09-17', 2558.3492700000006),
#  ('Brainsphere', '2016-09-18', 659.86428),
#  ('Brainsphere', '2016-09-19', 660.16412),
#  ('Brainsphere', '2016-09-21', 676.6712),
#  ('Brainsphere', '2016-09-22', 712.4892),
#  ('Brainsphere', '2016-09-25', 492.53009399999996),
#  ('Brainsphere', '2016-09-26', 1427.0643300000002),
#  ('Brainsphere', '2016-09-27', 1089.5742),
#  ('Brainsphere', '2016-09-28', 1622.989075),
#  ('Brainsphere', '2016-09-29', 585.7362),
#  ('Brainsphere', '2016-09-30', 371.482724),
#  ('Brainsphere', '2016-10-03', 1529.6915119999999),
#  ('Brainsphere', '2016-10-04', 440.66976300000005),
#  ('Brainsphere', '2016-10-05', 980.570115),
#  ('Brainsphere', '2016-10-06', 1847.012605),
#  ('Brainsphere', '2016-10-07', 327.86134000000004),
#  ('Brainsphere', '2016-10-09', 702.53296),
#  ('Brainsphere', '2016-10-10', 1145.295),
#  ('Brainsphere', '2016-10-11', 721.7303760000001),
#  ('Brainsphere', '2016-10-16', 263.068822),
#  ('Brainsphere', '2016-10-17', 444.03666599999997),
#  ('Brainsphere', '2016-10-19', 1122.2075060000002),
#  ('Brainsphere', '2016-10-20', 843.22008),
#  ('Brainsphere', '2016-10-21', 34.715454),
#  ('Brainsphere', '2016-10-23', 1613.03305),
#  ('Brainsphere', '2016-10-24', 845.8059509999999),
#  ('Brainsphere', '2016-10-25', 1290.94128),
#  ('Brainsphere', '2016-10-28', 696.6597700000001),
#  ('Brainsphere', '2016-10-29', 2442.880052),
#  ('Brainsphere', '2016-10-30', 1769.8991780000001),
#  ('Brainsphere', '2016-10-31', 2918.4663039999996),
#  ('Brainsphere', '2016-11-01', 204.95475000000002),
#  ('Brainsphere', '2016-11-03', 797.482056),
#  ('Brainsphere', '2016-11-05', 434.52390299999996),
#  ('Brainsphere', '2016-11-06', 188.24820999999997),
#  ('Brainsphere', '2016-11-08', 2394.6389099999997),
#  ('Brainsphere', '2016-11-09', 1569.687108),
#  ('Brainsphere', '2016-11-11', 660.5643200000001),
#  ('Brainsphere', '2016-11-12', 434.50259200000005),
#  ('Brainsphere', '2016-11-13', 1662.620112),
#  ('Brainsphere', '2016-11-14', 693.8663680000001),
#  ('Brainsphere', '2016-11-15', 1196.2068),
#  ('Brainsphere', '2016-11-17', 509.05750000000006),
#  ('Brainsphere', '2016-11-18', 927.4227659999999),
#  ('Brainsphere', '2016-11-22', 1149.417654),
#  ('Brainsphere', '2016-11-23', 1307.4174360000002),
#  ('Brainsphere', '2016-11-25', 859.91152),
#  ('Brainsphere', '2016-11-27', 2586.375744),
#  ('Brainsphere', '2016-11-28', 682.0154319999999),
#  ('Brainsphere', '2016-11-29', 1138.13624),
#  ('Brainsphere', '2016-11-30', 1691.8157999999999),
#  ('Brainsphere', '2016-12-03', 215.66013),
#  ('Brainsphere', '2016-12-04', 485.849868),
#  ('Brainsphere', '2016-12-05', 1291.9026319999998),
#  ('Brainsphere', '2016-12-06', 650.10471),
#  ('Brainsphere', '2016-12-07', 1075.33914),
#  ('Brainsphere', '2016-12-10', 1059.975774),
#  ('Brainsphere', '2016-12-11', 1716.967313),
#  ('Brainsphere', '2016-12-12', 259.40067600000003),
#  ('Brainsphere', '2016-12-14', 250.304304),
#  ('Brainsphere', '2016-12-17', 808.594501),
#  ('Brainsphere', '2016-12-19', 2686.21839),
#  ('Brainsphere', '2016-12-20', 392.50540800000005),
#  ('Brainsphere', '2016-12-21', 903.750804),
#  ('Brainsphere', '2016-12-22', 877.755536),
#  ('Brainsphere', '2016-12-26', 990.186786),
#  ('Brainsphere', '2016-12-27', 746.201245),
#  ('Brainsphere', '2016-12-30', 850.468962),
#  ('Brainsphere', '2016-12-31', 1826.43907),
#  ('Brainsphere', '2017-01-06', 939.3925459999999),
#  ('Brainsphere', '2017-01-07', 936.332325),
#  ('Brainsphere', '2017-01-08', 1061.250758),
#  ('Brainsphere', '2017-01-10', 1706.88751),
#  ('Brainsphere', '2017-01-11', 913.8240179999999),
#  ('Brainsphere', '2017-01-12', 2203.0777000000003),
#  ('Brainsphere', '2017-01-13', 959.0742210000001),
#  ('Brainsphere', '2017-01-15', 576.920015),
#  ('Brainsphere', '2017-01-16', 1044.716716),
#  ('Brainsphere', '2017-01-18', 2025.5094960000001),
#  ('Brainsphere', '2017-01-20', 1670.4041519999998),
#  ('Brainsphere', '2017-01-21', 154.94013599999997),
#  ('Brainsphere', '2017-01-24', 1832.2223079999999),
#  ('Brainsphere', '2017-01-25', 426.357441),
#  ('Brainsphere', '2017-01-26', 1709.2394000000002),
#  ('Brainsphere', '2017-01-27', 943.1963860000001),
#  ('Brainsphere', '2017-01-28', 1215.860954),
#  ('Brainsphere', '2017-01-29', 1009.5788010000001),
#  ('Brainsphere', '2017-01-31', 906.4851749999999),
#  ('Brainsphere', '2017-02-01', 401.23694),
#  ('Brainsphere', '2017-02-03', 1174.216861),
#  ('Brainsphere', '2017-02-04', 3064.901386),
#  ('Brainsphere', '2017-02-05', 292.17668199999997),
#  ('Brainsphere', '2017-02-06', 218.80331199999998),
#  ('Brainsphere', '2017-02-07', 603.532475),
#  ('Brainsphere', '2017-02-08', 566.56746),
#  ('Brainsphere', '2017-02-10', 1018.5664409999999),
#  ('Brainsphere', '2017-02-14', 212.94865800000002),
#  ('Brainsphere', '2017-02-15', 684.7028500000001),
#  ('Brainsphere', '2017-02-17', 1042.3368),
#  ('Brainsphere', '2017-02-18', 609.0522),
#  ('Brainsphere', '2017-02-19', 701.4622499999999),
#  ('Brainsphere', '2017-02-20', 1150.3816080000001),
#  ('Brainsphere', '2017-02-21', 715.8205580000001),
#  ('Brainsphere', '2017-02-22', 390.43179399999997),
#  ('Brainsphere', '2017-02-23', 1709.8972789999998),
#  ('Brainsphere', '2017-02-25', 934.5362009999999),
#  ('Brainsphere', '2017-02-27', 1524.84561),
#  ('Brainsphere', '2017-03-01', 1017.845922),
#  ('Brainsphere', '2017-03-02', 1892.9826159999998),
#  ('Brainsphere', '2017-03-03', 1296.779795),
#  ('Brainsphere', '2017-03-04', 1167.738885),
#  ('Brainsphere', '2017-03-05', 516.37494),
#  ('Brainsphere', '2017-03-06', -18.970271999999998),
#  ('Brainsphere', '2017-03-08', 899.1811920000001),
#  ('Brainsphere', '2017-03-10', 495.947166),
#  ('Brainsphere', '2017-03-11', 1173.1932960000001),
#  ('Brainsphere', '2017-03-12', 1154.7176439999998),
#  ('Brainsphere', '2017-03-14', 3075.9203849999994),
#  ('Brainsphere', '2017-03-15', 564.336238),
#  ('Brainsphere', '2017-03-18', 1095.539058),
#  ('Brainsphere', '2017-03-20', 265.165824),
#  ('Brainsphere', '2017-03-22', 1763.216085),
#  ('Brainsphere', '2017-03-24', 1620.804025),
#  ('Brainsphere', '2017-03-25', 201.718545),
#  ('Brainsphere', '2017-03-26', 1027.868845),
#  ('Brainsphere', '2017-03-27', 950.707701),
#  ('Brainsphere', '2017-03-28', 513.902175),
#  ('Brainsphere', '2017-03-29', 913.397284),
#  ('Brainsphere', '2017-03-30', 203.30509500000002),
#  ('Brainsphere', '2017-03-31', 1466.9548739999998),
#  ('Brainsphere', '2017-04-01', 2705.3040949999995),
#  ('Brainsphere', '2017-04-03', 799.5216950000001),
#  ('Brainsphere', '2017-04-04', 597.989744),
#  ('Brainsphere', '2017-04-05', 127.98650800000001),
#  ('Brainsphere', '2017-04-06', 570.396348),
#  ('Brainsphere', '2017-04-07', 1157.3944000000001),
#  ('Brainsphere', '2017-04-10', 1381.1059920000002),
#  ('Brainsphere', '2017-04-11', 2104.537072),
#  ('Brainsphere', '2017-04-12', 731.82984),
#  ('Brainsphere', '2017-04-13', 1570.99707),
#  ('Brainsphere', '2017-04-14', 1457.80883),
#  ('Brainsphere', '2017-04-15', 197.78178),
#  ('Brainsphere', '2017-04-16', 1071.37644),
#  ('Brainsphere', '2017-04-20', 296.056985),
#  ('Brainsphere', '2017-04-22', 2048.495832),
#  ('Brainsphere', '2017-04-23', 136.624158),
#  ('Brainsphere', '2017-04-24', 2892.4781759999996),
#  ('Brainsphere', '2017-04-26', 1164.537951),
#  ('Brainsphere', '2017-04-27', 913.155282),
#  ('Brainsphere', '2017-04-28', 233.20248),
#  ('Brainsphere', '2017-04-29', 1269.5960099999998),
#  ('Brainsphere', '2017-05-02', 1515.5586649999998),
#  ('Brainsphere', '2017-05-03', 677.174542),
#  ('Brainsphere', '2017-05-04', 768.179027),
#  ('Brainsphere', '2017-05-05', 568.4374600000001),
#  ('Brainsphere', '2017-05-06', 215.427494),
#  ('Brainsphere', '2017-05-07', 945.704119),
#  ('Brainsphere', '2017-05-08', 1348.950726),
#  ('Brainsphere', '2017-05-10', 3122.622546),
#  ('Brainsphere', '2017-05-11', 993.65742),
#  ('Brainsphere', '2017-05-13', 794.6766919999999),
#  ('Brainsphere', '2017-05-14', 538.568644),
#  ('Brainsphere', '2017-05-16', 809.1649120000001),
#  ('Brainsphere', '2017-05-18', 265.638101),
#  ('Brainsphere', '2017-05-21', 1330.569296),
#  ('Brainsphere', '2017-05-24', 207.977133),
#  ('Brainsphere', '2017-05-25', 277.524072),
#  ('Brainsphere', '2017-05-27', 721.8844919999999),
#  ('Brainsphere', '2017-05-29', 327.909092),
#  ('Brainsphere', '2017-05-30', 1151.71284),
#  ('Brainsphere', '2017-05-31', 1178.2835470000002),
#  ('Brainsphere', '2017-06-02', 1177.33632),
#  ('Brainsphere', '2017-06-03', 312.98795099999995),
#  ('Brainsphere', '2017-06-04', 689.520207),
#  ('Brainsphere', '2017-06-05', 1206.8264669999999),
#  ('Brainsphere', '2017-06-06', 1525.7404499999998),
#  ('Brainsphere', '2017-06-07', 489.487446),
#  ('Brainsphere', '2017-06-08', 1895.6910090000001),
#  ('Brainsphere', '2017-06-10', 1356.051136),
#  ('Brainsphere', '2017-06-12', 3209.531409),
#  ('Brainsphere', '2017-06-13', 904.516446),
#  ('Brainsphere', '2017-06-14', 1523.2270980000003),
#  ('Brainsphere', '2017-06-16', 1868.90912),
#  ('Brainsphere', '2017-06-17', 1321.83779),
#  ('Brainsphere', '2017-06-18', 1899.1046880000001),
#  ('Brainsphere', '2017-06-19', 2105.658378),
#  ('Brainsphere', '2017-06-20', 873.7825439999999),
#  ('Brainsphere', '2017-06-21', 763.1236200000001),
#  ('Brainsphere', '2017-06-24', 1091.300429),
#  ('Brainsphere', '2017-06-29', 1907.9682750000002),
#  ('Brainsphere', '2017-06-30', 553.36788),
#  ('Brainsphere', '2017-07-01', 1064.22606),
#  ('Brainsphere', '2017-07-02', 1194.961932),
#  ('Brainsphere', '2017-07-04', 1171.243598),
#  ('Brainsphere', '2017-07-05', 2284.300257),
#  ('Brainsphere', '2017-07-06', 1005.18165),
#  ('Brainsphere', '2017-07-07', 1265.5908),
#  ('Brainsphere', '2017-07-08', 2579.317416),
#  ('Brainsphere', '2017-07-09', 1472.193648),
#  ('Brainsphere', '2017-07-10', 2142.748725),
#  ('Brainsphere', '2017-07-11', 210.49068000000003),
#  ('Brainsphere', '2017-07-12', 1249.7842890000002),
#  ('Brainsphere', '2017-07-13', 217.596603),
#  ('Brainsphere', '2017-07-14', 234.544005),
#  ('Brainsphere', '2017-07-16', 1518.1607549999999),
#  ('Brainsphere', '2017-07-17', 407.0843920000001),
#  ('Brainsphere', '2017-07-18', 1178.74866),
#  ('Brainsphere', '2017-07-19', 384.429489),
#  ('Brainsphere', '2017-07-20', 598.5292900000001),
#  ('Brainsphere', '2017-07-22', 2374.3975419999997),
#  ('Brainsphere', '2017-07-23', 416.20149999999995),
#  ('Brainsphere', '2017-07-26', 1328.0680640000003),
#  ('Brainsphere', '2017-07-27', 2478.5666880000003),
#  ('Brainsphere', '2017-07-28', 1565.340611),
#  ('Brainsphere', '2017-07-29', 128.819607),
#  ('Brainsphere', '2017-07-31', 1284.0830460000002),
#  ('Brainsphere', '2017-08-02', 1733.587266),
#  ('Brainsphere', '2017-08-03', 2026.35216),
#  ('Brainsphere', '2017-08-05', 2701.026252),
#  ('Brainsphere', '2017-08-07', 968.993783),
#  ('Brainsphere', '2017-08-08', 399.37227),
#  ('Brainsphere', '2017-08-10', 186.691316),
#  ('Brainsphere', '2017-08-11', 1462.7659800000001),
#  ('Brainsphere', '2017-08-13', 562.2375850000001),
#  ('Brainsphere', '2017-08-15', 1153.8127680000002),
#  ('Brainsphere', '2017-08-16', 187.04382999999999),
#  ('Brainsphere', '2017-08-17', 1501.5555869999998),
#  ('Brainsphere', '2017-08-18', 250.16765999999998),
#  ('Brainsphere', '2017-08-20', 1071.41588),
#  ('Brainsphere', '2017-08-21', 62.45091),
#  ('Brainsphere', '2017-08-23', 2000.4968519999998),
#  ('Brainsphere', '2017-08-24', 1338.7767880000001),
#  ('Brainsphere', '2017-08-26', 756.2315520000001),
#  ('Brainsphere', '2017-08-29', 734.000304),
#  ('Brainsphere', '2017-08-30', 237.831444),
#  ('Brainsphere', '2017-08-31', 2045.7723000000005),
#  ('Brainsphere', '2017-09-02', 512.03552),
#  ('Brainsphere', '2017-09-03', 2609.3952799999997),
#  ('Brainsphere', '2017-09-04', 2123.6139),
#  ('Brainsphere', '2017-09-08', 1780.4539799999998),
#  ('Brainsphere', '2017-09-09', 1427.5301399999998),
#  ('Brainsphere', '2017-09-10', 627.55416),
#  ('Brainsphere', '2017-09-13', 1643.0156820000002),
#  ('Brainsphere', '2017-09-14', 1831.19326),
#  ('Brainsphere', '2017-09-16', 606.1053949999999),
#  ('Brainsphere', '2017-09-17', 1340.3225569999997),
#  ('Brainsphere', '2017-09-18', 585.2488840000001),
#  ('Brainsphere', '2017-09-19', 296.151364),
#  ('Brainsphere', '2017-09-20', 1076.2954730000001),
#  ('Brainsphere', '2017-09-21', 666.215705),
#  ('Brainsphere', '2017-09-22', 1207.714131),
#  ('Brainsphere', '2017-09-23', 556.007085),
#  ('Brainsphere', '2017-09-24', 2321.642061),
#  ('Brainsphere', '2017-09-25', 1062.92719),
#  ('Brainsphere', '2017-09-26', 929.4285240000002),
#  ('Brainsphere', '2017-09-27', 818.3946639999999),
#  ('Brainsphere', '2017-09-28', 1183.229658),
#  ('Brainsphere', '2017-09-29', 527.244154),
#  ('Brainsphere', '2017-09-30', 2658.982738),
#  ('Brainsphere', '2017-10-01', 2714.152176),
#  ('Brainsphere', '2017-10-02', 612.931104),
#  ('Brainsphere', '2017-10-03', 1256.489724),
#  ('Brainsphere', '2017-10-04', 693.1581090000001),
#  ('Brainsphere', '2017-10-05', 1041.5154),
#  ('Brainsphere', '2017-10-06', 372.387963),
#  ('Brainsphere', '2017-10-08', 367.78711200000004),
#  ('Brainsphere', '2017-10-09', 596.144738),
#  ('Brainsphere', '2017-10-10', 1365.6915020000001),
#  ('Brainsphere', '2017-10-12', 1121.530176),
#  ('Brainsphere', '2017-10-13', 1162.77717),
#  ('Brainsphere', '2017-10-16', 1573.7766109999998),
#  ('Brainsphere', '2017-10-17', 691.864283),
#  ('Brainsphere', '2017-10-18', 920.663389),
#  ('Brainsphere', '2017-10-19', 1185.2461039999998),
#  ('Brainsphere', '2017-10-22', 878.9282959999999),
#  ('Brainsphere', '2017-10-24', 416.86864499999996),
#  ('Brainsphere', '2017-10-25', 394.385025),
#  ('Brainsphere', '2017-10-26', 1473.403092),
#  ('Brainsphere', '2017-10-27', 1429.515505),
#  ('Brainsphere', '2017-10-28', 484.12578500000006),
#  ('Brainsphere', '2017-10-30', 196.88146),
#  ('Brainsphere', '2017-10-31', 1589.494764),
#  ('Brainsphere', '2017-11-01', 2421.2645679999996),
#  ('Brainsphere', '2017-11-02', 898.0740450000001),
#  ('Brainsphere', '2017-11-03', 1011.8975419999999),
#  ('Brainsphere', '2017-11-04', 216.33060600000002),
#  ('Brainsphere', '2017-11-08', 1636.55436),
#  ('Brainsphere', '2017-11-09', 1723.6357799999998),
#  ('Brainsphere', '2017-11-10', 1071.06087),
#  ('Brainsphere', '2017-11-12', 932.215114),
#  ('Brainsphere', '2017-11-13', 593.500208),
#  ('Brainsphere', '2017-11-14', 1236.5018550000002),
#  ('Brainsphere', '2017-11-15', 2104.53632),
#  ('Brainsphere', '2017-11-17', 1288.4150300000001),
#  ('Brainsphere', '2017-11-19', 1244.3725),
#  ('Brainsphere', '2017-11-21', 1882.590444),
#  ('Brainsphere', '2017-11-22', 405.187763),
#  ('Brainsphere', '2017-11-25', 989.59164),
#  ('Brainsphere', '2017-11-26', 148.355607),
#  ('Brainsphere', '2017-11-27', 1895.8381920000002),
#  ('Brainsphere', '2017-11-28', 1180.4665120000002),
#  ('Brainsphere', '2017-11-29', 1571.654549),
#  ('Brainsphere', '2017-12-01', 1599.98247),
#  ('Brainsphere', '2017-12-02', 1555.62765),
#  ('Brainsphere', '2017-12-03', 1921.2459049999998),
#  ('Brainsphere', '2017-12-07', 1677.61924),
#  ('Brainsphere', '2017-12-08', 1621.8872339999998),
#  ('Brainsphere', '2017-12-10', 1346.267268),
#  ('Brainsphere', '2017-12-12', 782.8390440000001),
#  ('Brainsphere', '2017-12-13', 2254.966776),
#  ('Brainsphere', '2017-12-14', 2170.2053650000003),
#  ('Brainsphere', '2017-12-16', 1906.7162240000002),
#  ('Brainsphere', '2017-12-17', 816.5147660000001),
#  ('Brainsphere', '2017-12-18', 2047.4822550000001),
#  ('Brainsphere', '2017-12-19', 3246.2174639999994),
#  ('Brainsphere', '2017-12-22', 948.998592),
#  ('Brainsphere', '2017-12-24', 2067.589908),
#  ('Brainsphere', '2017-12-25', 1006.3671119999999),
#  ('Brainsphere', '2017-12-26', 1040.622282),
#  ('Brainsphere', '2017-12-28', 641.27349),
#  ('Brainsphere', '2017-12-29', 2155.645806),
#  ('Brainsphere', '2017-12-30', 169.485076),
#  ('Brainsphere', '2017-12-31', 1154.506145),
#  ('Brainsphere', '2018-01-01', 1304.154799),
#  ('Brainsphere', '2018-01-02', 1035.9250299999999),
#  ('Brainsphere', '2018-01-03', 1634.995747),
#  ('Brainsphere', '2018-01-04', 2648.0382649999997),
#  ('Brainsphere', '2018-01-06', -66.63293999999999),
#  ('Brainsphere', '2018-01-07', 1392.751305),
#  ('Brainsphere', '2018-01-08', 3559.177791),
#  ('Brainsphere', '2018-01-11', 578.089802),
#  ('Brainsphere', '2018-01-13', 263.202982),
#  ('Brainsphere', '2018-01-15', 457.07271000000003),
#  ('Brainsphere', '2018-01-17', 3593.954342),
#  ('Brainsphere', '2018-01-19', 652.35816),
#  ('Brainsphere', '2018-01-20', 3170.3317349999998),
#  ('Brainsphere', '2018-01-23', 444.993921),
#  ('Brainsphere', '2018-01-25', 1163.503646),
#  ('Brainsphere', '2018-01-27', 390.316296),
#  ('Brainsphere', '2018-01-28', 145.99864000000002),
#  ('Brainsphere', '2018-01-29', 1526.305942),
#  ('Brainsphere', '2018-01-30', 1412.4167519999999),
#  ('Brainsphere', '2018-02-02', 579.491388),
#  ('Brainsphere', '2018-02-03', 977.37408),
#  ('Brainsphere', '2018-02-04', 1991.2997520000001),
#  ('Brainsphere', '2018-02-05', 178.92452),
#  ('Brainsphere', '2018-02-06', 1229.151984),
#  ('Brainsphere', '2018-02-07', 1296.563406),
#  ('Brainsphere', '2018-02-08', 674.4358440000001),
#  ('Brainsphere', '2018-02-09', 1815.188973),
#  ('Brainsphere', '2018-02-11', 885.791502),
#  ('Brainsphere', '2018-02-13', 829.751907),
#  ('Brainsphere', '2018-02-14', 394.5186),
#  ('Brainsphere', '2018-02-16', 814.33544),
#  ('Brainsphere', '2018-02-18', 955.1163199999999),
#  ('Brainsphere', '2018-02-19', 1270.7343600000002),
#  ('Brainsphere', '2018-02-20', 410.09522),
#  ('Brainsphere', '2018-02-24', 1626.456657),
#  ('Brainsphere', '2018-02-25', 4090.917978),
#  ('Brainsphere', '2018-02-27', 177.232808),
#  ('Brainsphere', '2018-03-01', 1947.2991450000002),
#  ('Brainsphere', '2018-03-02', 726.444936),
#  ('Brainsphere', '2018-03-03', 158.19688800000003),
#  ('Brainsphere', '2018-03-04', 1961.498592),
#  ('Brainsphere', '2018-03-07', 964.515309),
#  ('Brainsphere', '2018-03-08', 1412.64033),
#  ('Brainsphere', '2018-03-09', 219.54184200000003),
#  ('Brainsphere', '2018-03-10', 949.4428770000001),
#  ('Brainsphere', '2018-03-11', 2021.1812040000004),
#  ('Brainsphere', '2018-03-12', 1098.580902),
#  ('Brainsphere', '2018-03-13', 528.6767580000001),
#  ('Brainsphere', '2018-03-14', 213.29103600000002),
#  ('Brainsphere', '2018-03-16', 1577.590949),
#  ('Brainsphere', '2018-03-18', 1476.6612440000001),
#  ('Brainsphere', '2018-03-19', 139.92871200000002),
#  ('Brainsphere', '2018-03-21', 601.264554),
#  ('Brainsphere', '2018-03-22', -195.220916),
#  ('Brainsphere', '2018-03-23', 1049.71865),
#  ('Brainsphere', '2018-03-24', 595.5710399999999),
#  ('Brainsphere', '2018-03-25', 829.5030479999999),
#  ('Brainsphere', '2018-03-26', 1075.090464),
#  ('Brainsphere', '2018-03-27', 1014.225576),
#  ('Brainsphere', '2018-03-29', 3639.906783),
#  ('Brainsphere', '2018-03-30', 1016.297685),
#  ('Brainsphere', '2018-04-01', 576.7090469999999),
#  ('Brainsphere', '2018-04-02', 1193.855616),
#  ('Brainsphere', '2018-04-03', 963.5810119999999),
#  ('Brainsphere', '2018-04-04', 795.644388),
#  ('Brainsphere', '2018-04-05', 1630.48192),
#  ('Brainsphere', '2018-04-06', 767.9281800000001),
#  ('Brainsphere', '2018-04-07', 657.39399),
#  ('Brainsphere', '2018-04-08', 860.0379660000001),
#  ('Brainsphere', '2018-04-09', 659.334448),
#  ('Brainsphere', '2018-04-10', 537.0112839999999),
#  ('Brainsphere', '2018-04-14', 1217.683254),
#  ('Brainsphere', '2018-04-16', 1472.8587900000002),
#  ('Brainsphere', '2018-04-17', 1143.726849),
#  ('Brainsphere', '2018-04-18', 2678.174108),
#  ('Brainsphere', '2018-04-20', 1178.759076),
#  ('Brainsphere', '2018-04-21', 585.526821),
#  ('Brainsphere', '2018-04-22', 513.937677),
#  ('Brainsphere', '2018-04-23', 1518.319708),
#  ('Brainsphere', '2018-04-25', 2130.69347),
#  ('Brainsphere', '2018-04-29', 2085.2011300000004),
#  ('Brainsphere', '2018-04-30', 1642.5024199999998),
#  ('Brainsphere', '2018-05-01', 1685.4432649999999),
#  ('Brainsphere', '2018-05-02', 566.0339940000001),
#  ('Brainsphere', '2018-05-04', 524.8047430000001),
#  ('Brainsphere', '2018-05-06', 418.412302),
#  ('Brainsphere', '2018-05-09', 805.503111),
#  ('Brainsphere', '2018-05-10', 402.771102),
#  ('Brainsphere', '2018-05-11', 1749.154446),
#  ('Brainsphere', '2018-05-13', 3762.2770379999997),
#  ('Brainsphere', '2018-05-14', 541.97748),
#  ('Brainsphere', '2018-05-16', 809.8907519999999),
#  ('Brainsphere', '2018-05-17', 2325.5613900000003),
#  ('Brainsphere', '2018-05-18', 1117.097982),
#  ('Brainsphere', '2018-05-20', 2083.2577919999994),
#  ('Brainsphere', '2018-05-21', 1764.825997),
#  ('Brainsphere', '2018-05-22', 455.991422),
#  ('Brainsphere', '2018-05-23', 366.378444),
#  ('Brainsphere', '2018-05-24', 1291.1355200000003),
#  ('Brainsphere', '2018-05-26', 524.0206999999999),
#  ('Brainsphere', '2018-05-29', 1524.2805979999998),
#  ('Brainsphere', '2018-05-30', 556.079392),
#  ('Brainsphere', '2018-06-01', 207.883235),
#  ('Brainsphere', '2018-06-02', 1785.695401),
#  ('Brainsphere', '2018-06-04', 579.0214209999999),
#  ('Brainsphere', '2018-06-05', 874.002175),
#  ('Brainsphere', '2018-06-06', 625.4274),
#  ('Brainsphere', '2018-06-07', 1551.770616),
#  ('Brainsphere', '2018-06-08', 312.18624000000005),
#  ('Brainsphere', '2018-06-10', 1343.0355479999998),
#  ('Brainsphere', '2018-06-11', 1094.07663),
#  ('Brainsphere', '2018-06-12', 795.855032),
#  ('Brainsphere', '2018-06-13', 3040.746956),
#  ('Brainsphere', '2018-06-14', 1665.8711400000002),
#  ('Brainsphere', '2018-06-18', 133.78176),
#  ('Brainsphere', '2018-06-19', 284.128556),
#  ('Brainsphere', '2018-06-20', 1215.6668439999999),
#  ('Brainsphere', '2018-06-22', 625.858688),
#  ('Brainsphere', '2018-06-23', 326.08576),
#  ('Brainsphere', '2018-06-25', 686.2751999999999),
#  ('Brainsphere', '2018-06-26', 1932.206224),
#  ('Brainsphere', '2018-06-27', 630.841728),
#  ('Brainsphere', '2018-06-28', 1153.5973020000001),
#  ('Brainsphere', '2018-06-30', 1456.713732),
#  ('Brainsphere', '2018-07-01', 289.654668),
#  ('Brainsphere', '2018-07-03', 693.4725850000001),
#  ('Brainsphere', '2018-07-06', 421.86469200000005),
#  ('Brainsphere', '2018-07-07', 833.189508),
#  ('Brainsphere', '2018-07-08', 1351.4137560000001),
#  ('Brainsphere', '2018-07-09', 583.543711),
#  ('Brainsphere', '2018-07-10', 1336.874968),
#  ('Brainsphere', '2018-07-13', 1807.6921799999998),
#  ('Brainsphere', '2018-07-14', 359.035191),
#  ('Brainsphere', '2018-07-15', 1029.6603479999999),
#  ('Brainsphere', '2018-07-17', 1009.775578),
#  ('Brainsphere', '2018-07-18', 132.469899),
#  ('Brainsphere', '2018-07-21', 328.69722),
#  ('Brainsphere', '2018-07-22', 2324.62899),
#  ('Brainsphere', '2018-07-23', 866.7379639999999),
#  ('Brainsphere', '2018-07-24', 2143.942194),
#  ('Brainsphere', '2018-07-25', 453.79411),
#  ('Brainsphere', '2018-07-26', 347.66058400000003),
#  ('Brainsphere', '2018-07-27', 1424.2833750000002),
#  ('Brainsphere', '2018-07-28', 1398.661875),
#  ('Brainsphere', '2018-07-30', 641.6852800000001),
#  ('Brainsphere', '2018-07-31', 1809.609048),
#  ('Brainsphere', '2018-08-03', 153.73799599999998),
#  ('Brainsphere', '2018-08-04', 995.5250800000001),
#  ('Brainsphere', '2018-08-05', 797.08058),
#  ('Brainsphere', '2018-08-06', 182.24088400000002),
#  ('Brainsphere', '2018-08-07', 677.405974),
#  ('Brainsphere', '2018-08-08', 183.68565),
#  ('Brainsphere', '2018-08-11', 1144.168),
#  ('Brainsphere', '2018-08-12', 553.072768),
#  ('Brainsphere', '2018-08-13', 1043.1692460000002),
#  ('Brainsphere', '2018-08-14', 1003.8420600000001),
#  ('Brainsphere', '2018-08-15', 506.78456500000004),
#  ('Brainsphere', '2018-08-16', 1069.78056),
#  ('Brainsphere', '2018-08-17', 1049.521176),
#  ('Brainsphere', '2018-08-18', 2660.1516209999995),
#  ('Brainsphere', '2018-08-19', 171.924363),
#  ('Brainsphere', '2018-08-21', 2775.83517),
#  ('Brainsphere', '2018-08-23', 593.0416429999999),
#  ('Brainsphere', '2018-08-25', 2084.04386),
#  ('Brainsphere', '2018-08-26', 735.02684),
#  ('Brainsphere', '2018-08-27', 1438.443716),
#  ('Brainsphere', '2018-08-28', 953.11203),
#  ('Brainsphere', '2018-08-29', 701.9669799999999),
#  ('Brainsphere', '2018-08-30', 1754.431368),
#  ('Brainsphere', '2018-08-31', 268.462342),
#  ('Brainsphere', '2018-09-01', 739.046232),
#  ('Brainsphere', '2018-09-04', 867.0921899999998),
#  ('Brainsphere', '2018-09-06', 1043.244048),
#  ('Brainsphere', '2018-09-07', 185.572855),
#  ('Brainsphere', '2018-09-09', 1034.420285),
#  ('Brainsphere', '2018-09-10', 823.137798),
#  ('Brainsphere', '2018-09-11', -140.369472),
#  ('Brainsphere', '2018-09-12', 1270.1678150000002),
#  ('Brainsphere', '2018-09-14', 152.179091),
#  ('Brainsphere', '2018-09-15', 176.363632),
#  ('Brainsphere', '2018-09-16', 354.22345600000006),
#  ('Brainsphere', '2018-09-19', 220.5063),
#  ('Brainsphere', '2018-09-20', 397.93342800000005),
#  ('Brainsphere', '2018-09-22', 960.510397),
#  ('Brainsphere', '2018-09-23', 563.891086),
#  ('Brainsphere', '2018-09-26', 2080.946626),
#  ('Brainsphere', '2018-09-28', 1003.789688),
#  ('Brainsphere', '2018-09-29', 1549.088744),
#  ('Brainsphere', '2018-10-01', 1230.0967280000002),
#  ('Brainsphere', '2018-10-02', 3169.1883650000004),
#  ('Brainsphere', '2018-10-04', 916.1918099999998),
#  ('Brainsphere', '2018-10-08', 366.389238),
#  ('Brainsphere', '2018-10-09', 398.12096),
#  ('Brainsphere', '2018-10-10', 1615.9685),
#  ('Brainsphere', '2018-10-11', 403.64340000000004),
#  ('Brainsphere', '2018-10-12', 731.430504),
#  ('Brainsphere', '2018-10-14', 237.46375799999998),
#  ('Brainsphere', '2018-10-15', 225.44732699999997),
#  ('Brainsphere', '2018-10-16', 782.9335900000001),
#  ('Brainsphere', '2018-10-17', 1003.87098),
#  ('Brainsphere', '2018-10-18', 149.093295),
#  ('Brainsphere', '2018-10-19', 1119.80463),
#  ('Brainsphere', '2018-10-20', 1029.15722),
#  ('Brainsphere', '2018-10-21', 935.67672),
#  ('Brainsphere', '2018-10-22', 964.5419979999999),
#  ('Brainsphere', '2018-10-24', 892.3053720000001),
#  ('Brainsphere', '2018-10-25', 759.27816),
#  ('Brainsphere', '2018-10-26', 1019.0646250000001),
#  ('Brainsphere', '2018-10-28', 400.60329500000006),
#  ('Brainsphere', '2018-10-29', 376.13066899999995),
#  ('Brainsphere', '2018-10-31', 1283.212204),
#  ('Brainsphere', '2018-11-04', 766.503129),
#  ('Brainsphere', '2018-11-05', 186.70677),
#  ('Brainsphere', '2018-11-06', 2379.801004),
#  ('Brainsphere', '2018-11-07', 1634.037237),
#  ('Brainsphere', '2018-11-08', 750.7738560000001),
#  ('Brainsphere', '2018-11-09', 400.162074),
#  ('Brainsphere', '2018-11-11', 129.435168),
#  ('Brainsphere', '2018-11-12', 1050.1458300000002),
#  ('Brainsphere', '2018-11-15', 507.0744700000001),
#  ('Brainsphere', '2018-11-16', 364.444866),
#  ('Brainsphere', '2018-11-17', 784.144752),
#  ('Brainsphere', '2018-11-18', 671.195322),
#  ('Brainsphere', '2018-11-19', 1349.3915760000002),
#  ('Brainsphere', '2018-11-20', 304.20975599999997),
#  ('Brainsphere', '2018-11-22', 433.18856700000003),
#  ('Brainsphere', '2018-11-24', 1038.401496),
#  ('Brainsphere', '2018-11-25', 752.217576),
#  ('Brainsphere', '2018-11-26', 1093.654661),
#  ('Brainsphere', '2018-11-27', 383.781312),
#  ('Brainsphere', '2018-11-28', 245.57369200000002),
#  ('Brainsphere', '2018-11-29', 843.218737),
#  ('Brainsphere', '2018-11-30', 1128.721112),
#  ('Brainsphere', '2018-12-01', 1074.3796559999998),
#  ('Brainsphere', '2018-12-03', 1868.81678),
#  ('Brainsphere', '2018-12-04', 1157.066553),
#  ('Brainsphere', '2018-12-06', 375.04839100000004),
#  ('Brainsphere', '2018-12-07', 1956.755793),
#  ('Brainsphere', '2018-12-08', 1440.012069),
#  ('Brainsphere', '2018-12-10', 350.37047500000006),
#  ('Brainsphere', '2018-12-11', 471.30680099999995),
#  ('Brainsphere', '2018-12-12', 1430.1065700000001),
#  ('Brainsphere', '2018-12-13', 1163.639914),
#  ('Brainsphere', '2018-12-14', 171.91569),
#  ('Brainsphere', '2018-12-16', 314.840215),
#  ('Brainsphere', '2018-12-17', 287.04071000000005),
#  ('Brainsphere', '2018-12-18', 1719.144339),
#  ('Brainsphere', '2018-12-21', 873.239484),
#  ('Brainsphere', '2018-12-22', 2244.882692),
#  ('Brainsphere', '2018-12-23', 764.635274),
#  ('Brainsphere', '2018-12-25', 409.125104),
#  ('Brainsphere', '2018-12-27', 983.8715829999999),
#  ('Brainsphere', '2018-12-28', 2777.1941100000004),
#  ('Brainsphere', '2018-12-30', 761.244294),
#  ('Brainsphere', '2018-12-31', 785.5845),
#  ('Bubblemix', '2016-02-12', 7267.957132161633),
#  ('Bubblemix', '2016-04-07', 11248.060467562827),
#  ('Bubblemix', '2016-04-11', 15101.351512189007),
#  ('Bubblemix', '2016-04-12', 17653.512464576703),
#  ('Bubblemix', '2016-05-29', -2202.0974643198297),
#  ('Bubblemix', '2016-06-03', 1976.80313104266),
#  ('Bubblemix', '2016-07-04', 6483.494187982185),
#  ('Bubblemix', '2016-07-14', 26925.301179019432),
#  ('Bubblemix', '2016-08-12', 6056.459442935118),
#  ('Bubblemix', '2016-08-25', 4496.163700146864),
#  ('Bubblemix', '2016-09-23', 11568.099253086935),
#  ('Bubblemix', '2016-10-27', 17364.823424792063),
#  ('Bubblemix', '2016-11-03', 5313.001345315293),
#  ('Bubblemix', '2016-11-05', 8523.427274706111),
#  ('Bubblemix', '2016-11-20', 14063.195962300933),
#  ('Bubblemix', '2016-11-21', 4125.964595937264),
#  ('Bubblemix', '2016-12-24', 15360.987331708751),
#  ('Bubblemix', '2017-01-11', 7744.333529192115),
#  ('Bubblemix', '2017-02-25', 6393.4522038396),
#  ('Bubblemix', '2017-03-01', 13078.773428992741),
#  ('Bubblemix', '2017-06-09', 4360.559997543381),
#  ('Bubblemix', '2017-07-09', 8434.449029993393),
#  ('Bubblemix', '2017-07-12', 13715.83894724461),
#  ('Bubblemix', '2017-07-28', 18233.839603084463),
#  ('Bubblemix', '2017-07-31', 12095.421866225352),
#  ('Bubblemix', '2017-08-04', 13163.20521998292),
#  ('Bubblemix', '2017-09-03', 1929.114444504744),
#  ('Bubblemix', '2017-09-05', 19374.51411295173),
#  ('Bubblemix', '2017-09-08', 3928.3988270395353),
#  ('Bubblemix', '2017-10-30', 3655.5701608778218),
#  ('Bubblemix', '2017-11-16', 8152.0127235822965),
#  ('Bubblemix', '2017-11-20', 13694.657678859932),
#  ('Bubblemix', '2017-11-22', 7568.954970078659),
#  ('Bubblemix', '2017-12-15', 6707.642558594348),
#  ('Bubblemix', '2017-12-28', -212.11342061563),
#  ('Bubblemix', '2018-02-03', 16001.620641209971),
#  ('Bubblemix', '2018-02-23', 9569.504084558544),
#  ('Bubblemix', '2018-02-26', 16472.0284722255),
#  ('Bubblemix', '2018-05-16', 12301.481597556145),
#  ('Bubblemix', '2018-05-31', 3512.4986698220578),
#  ('Bubblemix', '2018-06-16', 7422.187495728097),
#  ('Bubblemix', '2018-07-08', 14296.43697510892),
#  ('Bubblemix', '2018-07-12', 10780.2626136071),
#  ('Bubblemix', '2018-07-17', 10400.015777296148),
#  ('Bubblemix', '2018-08-21', 2805.6128026215956),
#  ('Bubblemix', '2018-09-19', 13162.777874676858),
#  ('Bubblemix', '2018-10-26', 6665.927867745567),
#  ('Bubblemix', '2018-10-28', 15384.949304320402),
#  ('Bubblemix', '2018-11-04', 2694.172381415658),
#  ...]

# %% [markdown]
# ---
